# %% [markdown]
# ## 심화통계

# %%
# Import Libraries
#초기 설정및 시스템 라이브러리
import platform
import warnings

# 데이터 시각화 라이브러리
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from datetime import datetime, timedelta
print(platform.system())
warnings.filterwarnings('ignore')

# 행,열,결과값 생략 없이 보기,세팅
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)
# %matplotlib inline

# 시각화 OS별 한글폰트 설정
if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows 폰트 설정
elif platform.system() == 'Mac':
    plt.rcParams['font.family'] = 'AppleGothic'  # Mac 폰트 설정
    
print("="*60)
print("라이브러리 로드 완료!")
print("한글 폰트 설정 완료!")
print("="*60)
# Out:
# Windows
# ============================================================
# 라이브러리 로드 완료!
# 한글 폰트 설정 완료!
# ============================================================

# %%
# Load Dataset
sf_master   = pd.read_csv("./data/stat/sf_master.csv")              # sf_master
print("="*60)
print("데이터셋 로드 완료!")
print("="*60)
# Out:
# ============================================================
# 데이터셋 로드 완료!
# ============================================================

# %%
print("[sf_master]", sf_master.duplicated().sum())
print("[sf_master]", sf_master.shape)
print(sf_master.columns)
# Out:
# [sf_master] 0
# [sf_master] (483539, 42)
# Index(['objects_cfpr_id', 'founded_at', 'closed_at', 'description',
#        'country_code', 'obj_city_fixed', 'first_investment_at',
#        'last_investment_at', 'investment_rounds', 'invested_companies',
#        'first_funding_at', 'last_funding_at', 'funding_rounds',
#        'funding_total_usd', 'relationships', 'cat_obj_status',
#        'obj_category_filled', 'cat_obj_overview', 'obj_state_filled',
#        'is_obj_funding_total_usd_private', 'offices_c_id', 'office_id',
#        'office_city', 'rel_cf_id_x', 'relationship_growth', 'cat_fr_type',
#        'num_fr_type', 'raised_amount_usd', 'is_fr_raised_private',
#        'rel_cf_id_y', 'rel_p_id', 'n_founding_max', 'degree_max', 'stem_ratio',
#        'co_founders', 'top_university', 'us_born_ratio', 'title_diversity',
#        'funding_round_id', 'success_flag', 'round_tempo_months', 'open_rate'],
#       dtype='object')

# %% [markdown]
# ### 여러변수로 성공률 설명하기

# %% [markdown]
# ##### 심화통계
# <span style = "font-size: 15px">
# <b>성공 vs 실패 다변량 로지스틱</b><br>
# </span>

# %% [markdown]
# <span style = "font-size:  13px;">
# 표본 단위(GRAIN)검증<br>
# 각 변수의 독립적 영향이 남는가<br>
# * grain: 1행 1스타트업<br>
# </span>

# %%
# 1) 타깃(성공여부) 정리: 0/1만 사용
sf_master = sf_master[sf_master["success_flag"].isin([0, 1])].copy()

# 2) 라운드-스타트업 유일성 확인(사용자 확인 사항)
dup_obj_fr = sf_master[["objects_cfpr_id", "funding_round_id"]].duplicated().sum()
print("dup (objects_cfpr_id, funding_round_id) =", dup_obj_fr)

# 3) 스타트업 중복(= 여러 라운드 존재) 확인
dup_obj = sf_master["objects_cfpr_id"].duplicated().sum()
print("dup objects_cfpr_id =", dup_obj)

# 4) 성공여부가 스타트업 내에서 변하는지 확인
flag_var = sf_master.groupby("objects_cfpr_id")["success_flag"].nunique().value_counts().sort_index()
print("success_flag nunique per startup:\n", flag_var)
# success_flag nunique가 전부 1이면: 스타트업 단위 집계가 합리적
# Out:
# dup (objects_cfpr_id, funding_round_id) = 0
# dup objects_cfpr_id = 20919
# success_flag nunique per startup:
#  success_flag
# 1    31707
# Name: count, dtype: int64

# %% [markdown]
# <span style = "font-size:  13px;">
# 스타트업 단위로 집계<br>
# <b>의사결정 근거</b><br>
# * 동일 스타트업의 여러 라운드 중 어떤 행을 고르느냐에 따라 결측이 달라질 수 있음<br>
# * 첫 행/마지막 행을 임의로 택하기보다 해당 스타트업에서 관측 가능한 값(비결측)을 최대한 살리는 coalesce 집계가 안전<br>
# * 성공여부는 스타트업에서 고정이므로 max로 집계해도 동일<br>
# </span>

# %%
def coalesce_first_nonnull(s: pd.Series):
    s2 = s.dropna()
    return s2.iloc[0] if len(s2) else np.nan

# 이번 분석에 필요한 컬럼만 선별(속도/메모리 절약)
USE_COLS = [
    "objects_cfpr_id",
    "success_flag",

    # 스타트업 특성
    "obj_category_filled",
    "obj_state_filled",
    "round_tempo_months",
    "is_obj_funding_total_usd_private",
    "title_diversity",
    "relationships",

    # 창업자 특성
    "degree_max",
    "stem_ratio",
    "top_university",
    "n_founding_max"
]

missing_cols = [c for c in USE_COLS if c not in sf_master.columns]
if missing_cols:
    print("[경고] 데이터에 없는 컬럼:", missing_cols)

use_cols_exist = [c for c in USE_COLS if c in sf_master.columns]
df = sf_master[use_cols_exist].copy()

# 스타트업 단위 집계
agg_dict = {c: coalesce_first_nonnull for c in df.columns if c not in ["objects_cfpr_id"]}
agg_dict["success_flag"] = "max"

df_s = (
    df.groupby("objects_cfpr_id", as_index=False)
      .agg(agg_dict)
)

print("startup-level shape:", df_s.shape)
print("dup objects_cfpr_id in df_s:", df_s["objects_cfpr_id"].duplicated().sum())
# Out:
# startup-level shape: (31707, 12)
# dup objects_cfpr_id in df_s: 0

# %% [markdown]
# <span style = "font-size: 15px">
# 범주 축약<br>
# </span>
# <span style = "font-size: 13px">
# <b>1. 산업/지역: Top-K + Others + Unknown</b><br>
# * 범주가 너무 많으면 계수가 폭증하고 일부 범주는 표본이 희박해 분산이 커짐<br>
# * Top-K를 유지하고 나머지는 Others로 묶는 것이 안정적<br>
# * 지역(state)은 결측이 많을 수 있으므로 Unknown을 명시<br>
# </span>

# %%
def topk_with_other_and_unknown(s: pd.Series, k: int, other="Others", unknown="Unknown"):
    s2 = s.fillna(unknown).astype(str)
    topk = s2.value_counts().head(k).index
    return s2.where(s2.isin(topk), other)

df_s["cat_top10"]   = topk_with_other_and_unknown(df_s["obj_category_filled"], k=10)
df_s["state_top10"] = topk_with_other_and_unknown(df_s["obj_state_filled"], k=10)

# %% [markdown]
# <span style = "font-size: 15px">
#  결측 처리<br>
# </span>
# <span style = "font-size: 13px">
# <b>2. 결측이 많은 연속형: 분위수 bin + Unknown</b><br>
# * round_tempo_months, title_diversity, stem_ratio, top_university는 결측이 많을 수 있음<br>
# * 단순 대치보다 “Unknown”을 분리하면 (1) 표본 유지 (2) 결측 집단의 구조적 차이를 모델이 흡수 가능<br>
# * 분위수 bin은 OR 해석이 직관적입니다(“상위 25% vs 하위 25%”)<br>
# </span>

# %%
def qbin_with_unknown(x: pd.Series, q=4, unknown="Unknown"):
    out = pd.Series([unknown]*len(x), index=x.index, dtype="object")
    mask = x.notna()
    if mask.sum() == 0:
        return out
    # duplicates='drop': 값이 너무 중복이면 bin 수가 줄어들 수 있음
    out.loc[mask] = pd.qcut(x.loc[mask], q=q, duplicates="drop").astype(str)
    return out

# 결측 많은 변수들은 bin 처리
if "round_tempo_months" in df_s.columns:
    df_s["tempo_q"] = qbin_with_unknown(df_s["round_tempo_months"], q=4)

if "title_diversity" in df_s.columns:
    df_s["titlediv_q"] = qbin_with_unknown(df_s["title_diversity"], q=4)

if "stem_ratio" in df_s.columns:
    df_s["stem_q"] = qbin_with_unknown(df_s["stem_ratio"], q=4)

if "top_university" in df_s.columns:
    df_s["topuni_q"] = qbin_with_unknown(df_s["top_university"], q=4)

# 창업경험: 분포가 치우치면 구간화가 해석에 유리
if "n_founding_max" in df_s.columns:
    nf = df_s["n_founding_max"]
    df_s["founding_bin"] = pd.Series(["Unknown"]*len(nf), index=nf.index, dtype="object")
    m = nf.notna()
    df_s.loc[m, "founding_bin"] = pd.cut(
        nf.loc[m],
        bins=[0, 1, 2, 4, np.inf],
        labels=["1", "2", "3-4", "5+"],
        include_lowest=True
    ).astype(str)

# 학력: 0~4 + Unknown (범주형 처리)
if "degree_max" in df_s.columns:
    df_s["degree_cat"] = df_s["degree_max"].map(
        {0:"0", 1:"1", 2:"2", 3:"3", 4:"4"}
    ).astype("object")
    df_s.loc[df_s["degree_max"].isna(), "degree_cat"] = "Unknown"

# %% [markdown]
# <span style = "font-size: 15px">
# 스케일링 함수<br>
# </span>
# <span style = "font-size: 13px">
# <b>3. 관계규모(relationships): log1p + 표준화(1SD OR)</b><br>
# * 관계수는 긴 꼬리(대형 outlier)가 많을 가능성이 큼 → log1p로 완화<br>
# * 표준화하면 OR이 “1 SD 증가당”으로 비교 가능<br>
# </span>

# %%
def zscore(s: pd.Series):
    return (s - s.mean()) / s.std(ddof=0)

df_s["log_rel"] = np.log1p(df_s["relationships"].clip(lower=0))
df_s["log_rel_z"] = zscore(df_s["log_rel"])

# %% [markdown]
# <span style = "font-size: 15px">
# 로지스틱 회귀 실행 + OR 테이블 생성 유틸<br>
# </span>

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm

ALPHA = 0.05

def fit_logit(df_in: pd.DataFrame, formula: str):
    # # GLM(Binomial)을 쓰면 robust covariance 지정
    # model = smf.glm(formula=formula, data=df_in, family=sm.families.Binomial()).fit(cov_type="HC1")
    # return model

     # 1) 먼저 non-robust로 적합(여기서는 거의 안 터짐)
    m = smf.glm(formula=formula, data=df_in, family=sm.families.Binomial()).fit()

    # 2) robust(=HC1) 표준오차는 사후에 시도
    try:
        m = m.get_robustcov_results(cov_type="HC1")
    except Exception as e:
        print("[경고] HC1 robust SE 계산 실패 → nonrobust SE로 진행합니다.")
        print("원인:", type(e).__name__, str(e)[:120])

    # “Singular matrix”가 나와도 코드가 멈추지 않고, 어떤 변수가 문제인지 후속 조치를 할 수 있는 상태가 됨

    return m

def or_table(model, alpha=0.05):
    coef = model.params
    se = model.bse
    p = model.pvalues
    ci = model.conf_int(alpha=alpha)
    out = pd.DataFrame({
        "coef(logit)": coef,
        "OR": np.exp(coef),
        "CI_low": np.exp(ci[0]),
        "CI_high": np.exp(ci[1]),
        "p_value": p,
    })
    out["결론(alpha=0.05)"] = np.where(out["p_value"] < alpha, "[귀무가설 기각]", "[귀무가설 기각 못함]")
    return out.sort_values("p_value")

# %% [markdown]
# ### Model A

# %% [markdown]
# <span style = "font-size: 15px;">
# Model A: 스타트업 특성이 성공률에 미치는 영향<br>
# 스타트업 특성: 산업, 지역, 사무실, 성장템포, 금액정보 공개율, 직무다양성, 규모<br>
# </span>
#
# <span style = "font-size: 13px;">
# 모델 A(core): 표본을 최대한 보존<br>
# </span>

# %%
formula_A_core = """
success_flag
~ C(cat_top10)
+ C(state_top10)
+ is_obj_funding_total_usd_private
+ log_rel_z
"""

mA_core = fit_logit(df_s, formula_A_core)
print(mA_core.summary())

tab_A_core = or_table(mA_core, alpha=ALPHA)
tab_A_core.head(30)
# Out:
# [경고] HC1 robust SE 계산 실패 → nonrobust SE로 진행합니다.
# 원인: AttributeError 'GLMResults' object has no attribute 'get_robustcov_results'
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           success_flag   No. Observations:                31707
# Model:                            GLM   Df Residuals:                    31684
# Model Family:                Binomial   Df Model:                           22
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -12849.
# Date:                    월, 19 1 2026   Deviance:                       25698.
# Time:                        09:50:17   Pearson chi2:                 3.22e+04
# No. Iterations:                     6   Pseudo R-squ. (CS):            0.08863
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           -1.5487      0.041    -37.793      0.000      -1.629      -1.468
# C(cat_top10)[T.advertising]          0.2768      0.078      3.537      0.000       0.123       0.430
# C(cat_top10)[T.biotech]              0.0310      0.062      0.501      0.616      -0.090       0.152
# C(cat_top10)[T.cleantech]            0.0098      0.099      0.099      0.921      -0.185       0.204
# C(cat_top10)[T.ecommerce]            0.1488      0.078      1.900      0.057      -0.005       0.302
# C(cat_top10)[T.enterprise]           0.2817      0.070      4.052      0.000       0.145       0.418
# C(cat_top10)[T.games_video]          0.1878      0.080      2.336      0.019       0.030       0.345
# C(cat_top10)[T.hardware]             0.0358      0.100      0.358      0.721      -0.160       0.232
# C(cat_top10)[T.mobile]               0.2219      0.066      3.385      0.001       0.093       0.350
# C(cat_top10)[T.software]             0.2353      0.047      4.971      0.000       0.143       0.328
# C(cat_top10)[T.web]                  0.3233      0.058      5.587      0.000       0.210       0.437
# C(state_top10)[T.CO]                -0.3481      0.128     -2.730      0.006      -0.598      -0.098
# C(state_top10)[T.FL]                -0.6520      0.146     -4.474      0.000      -0.938      -0.366
# C(state_top10)[T.IL]                -0.5166      0.136     -3.791      0.000      -0.784      -0.249
# C(state_top10)[T.MA]                -0.1616      0.071     -2.283      0.022      -0.300      -0.023
# C(state_top10)[T.NY]                -0.2377      0.064     -3.733      0.000      -0.363      -0.113
# C(state_top10)[T.Others]            -0.6513      0.053    -12.383      0.000      -0.754      -0.548
# C(state_top10)[T.PA]                -0.7318      0.145     -5.049      0.000      -1.016      -0.448
# C(state_top10)[T.TX]                -0.3751      0.098     -3.835      0.000      -0.567      -0.183
# C(state_top10)[T.Unknown]           -0.4181      0.042     -9.949      0.000      -0.500      -0.336
# C(state_top10)[T.WA]                -0.1353      0.097     -1.390      0.164      -0.326       0.055
# is_obj_funding_total_usd_private    -0.6418      0.063    -10.224      0.000      -0.765      -0.519
# log_rel_z                            0.6965      0.017     40.441      0.000       0.663       0.730
# ====================================================================================================
#                                   coef(logit)        OR    CI_low   CI_high  \
# Intercept                           -1.548683  0.212528  0.196126  0.230301
# log_rel_z                            0.696509  2.006735  1.940125  2.075631
# C(state_top10)[T.Others]            -0.651318  0.521358  0.470289  0.577974
# is_obj_funding_total_usd_private    -0.641850  0.526318  0.465382  0.595232
# C(state_top10)[T.Unknown]           -0.418117  0.658285  0.606234  0.714805
# C(cat_top10)[T.web]                  0.323346  1.381743  1.233572  1.547712
# C(state_top10)[T.PA]                -0.731756  0.481063  0.362112  0.639089
# C(cat_top10)[T.software]             0.235250  1.265225  1.153158  1.388184
# C(state_top10)[T.FL]                -0.652048  0.520978  0.391524  0.693234
# C(cat_top10)[T.enterprise]           0.281702  1.325384  1.156553  1.518860
# C(state_top10)[T.TX]                -0.375144  0.687190  0.567298  0.832420
# C(state_top10)[T.IL]                -0.516604  0.596543  0.456706  0.779196
# C(state_top10)[T.NY]                -0.237733  0.788413  0.695888  0.893240
# C(cat_top10)[T.advertising]          0.276782  1.318879  1.131330  1.537519
# C(cat_top10)[T.mobile]               0.221911  1.248460  1.097931  1.419628
# C(state_top10)[T.CO]                -0.348105  0.706025  0.549894  0.906486
# C(cat_top10)[T.games_video]          0.187781  1.206569  1.030706  1.412439
# C(state_top10)[T.MA]                -0.161578  0.850800  0.740617  0.977375
# C(cat_top10)[T.ecommerce]            0.148829  1.160475  0.995354  1.352988
# C(state_top10)[T.WA]                -0.135323  0.873434  0.721753  1.056991
# C(cat_top10)[T.biotech]              0.030992  1.031477  0.913735  1.164391
# C(cat_top10)[T.hardware]             0.035768  1.036415  0.851889  1.260911
# C(cat_top10)[T.cleantech]            0.009816  1.009865  0.831407  1.226628
#
#                                        p_value 결론(alpha=0.05)
# Intercept                         0.000000e+00      [귀무가설 기각]
# log_rel_z                         0.000000e+00      [귀무가설 기각]
# C(state_top10)[T.Others]          3.237720e-35      [귀무가설 기각]
# is_obj_funding_total_usd_private  1.551108e-24      [귀무가설 기각]
# C(state_top10)[T.Unknown]         2.555173e-23      [귀무가설 기각]
# C(cat_top10)[T.web]               2.309926e-08      [귀무가설 기각]
# C(state_top10)[T.PA]              4.435451e-07      [귀무가설 기각]
# C(cat_top10)[T.software]          6.645478e-07      [귀무가설 기각]
# C(state_top10)[T.FL]              7.683774e-06      [귀무가설 기각]
# C(cat_top10)[T.enterprise]        5.076694e-05      [귀무가설 기각]
# C(state_top10)[T.TX]              1.255709e-04      [귀무가설 기각]
# C(state_top10)[T.IL]              1.502525e-04      [귀무가설 기각]
# C(state_top10)[T.NY]              1.895432e-04      [귀무가설 기각]
# C(cat_top10)[T.advertising]       4.051999e-04      [귀무가설 기각]
# C(cat_top10)[T.mobile]            7.113721e-04      [귀무가설 기각]
# C(state_top10)[T.CO]              6.335276e-03      [귀무가설 기각]
# C(cat_top10)[T.games_video]       1.947898e-02      [귀무가설 기각]
# C(state_top10)[T.MA]              2.240919e-02      [귀무가설 기각]
# C(cat_top10)[T.ecommerce]         5.736779e-02   [귀무가설 기각 못함]
# C(state_top10)[T.WA]              1.643912e-01   [귀무가설 기각 못함]
# C(cat_top10)[T.biotech]           6.162621e-01   [귀무가설 기각 못함]
# C(cat_top10)[T.hardware]          7.206822e-01   [귀무가설 기각 못함]
# C(cat_top10)[T.cleantech]         9.211830e-01   [귀무가설 기각 못함]

# %% [markdown]
# <span style = "font-size: 15px;">
# 모델 A(extended): 성장템포/직무다양성까지 포함(결측은 bin+Unknown으로 유지)<br>
# </span>

# %%
terms = [
    "C(cat_top10)",
    "C(state_top10)",
    "is_obj_funding_total_usd_private",
    "log_rel_z",
]

if "tempo_q" in df_s.columns:
    terms.append("C(tempo_q)")
if "titlediv_q" in df_s.columns:
    terms.append("C(titlediv_q)")

formula_A_ext = "success_flag ~ " + " + ".join(terms)

mA_ext = fit_logit(df_s, formula_A_ext)
tab_A_ext = or_table(mA_ext, alpha=ALPHA)
tab_A_ext.head(40)

# 해석
# OR > 1: 해당 특성이 있을수록 성공 odds 증가
# OR < 1: 성공 odds 감소
# Unknown 범주의 OR은 “정보가 관측되는 집단과 다른 구조적 차이”일 수 있음(인과 해석 금지)
# Out:
# [경고] HC1 robust SE 계산 실패 → nonrobust SE로 진행합니다.
# 원인: AttributeError 'GLMResults' object has no attribute 'get_robustcov_results'
#                                   coef(logit)        OR    CI_low   CI_high  \
# log_rel_z                            0.660061  1.934910  1.864445  2.008038
# Intercept                           -1.536183  0.215201  0.168015  0.275640
# C(state_top10)[T.Others]            -0.638788  0.527932  0.476044  0.585476
# is_obj_funding_total_usd_private    -0.628234  0.533533  0.471603  0.603596
# C(state_top10)[T.Unknown]           -0.410774  0.663137  0.610591  0.720206
# C(cat_top10)[T.web]                  0.332241  1.394089  1.244212  1.562020
# C(cat_top10)[T.software]             0.244517  1.277005  1.163567  1.401502
# C(state_top10)[T.PA]                -0.726501  0.483598  0.363940  0.642598
# C(state_top10)[T.FL]                -0.637336  0.528699  0.397184  0.703761
# C(cat_top10)[T.enterprise]           0.270875  1.311111  1.143532  1.503248
# C(state_top10)[T.NY]                -0.242296  0.784824  0.692470  0.889495
# C(state_top10)[T.IL]                -0.509374  0.600871  0.459893  0.785067
# C(state_top10)[T.TX]                -0.363514  0.695229  0.573758  0.842417
# C(cat_top10)[T.advertising]          0.273615  1.314709  1.127361  1.533191
# C(cat_top10)[T.mobile]               0.227971  1.256049  1.104363  1.428569
# C(titlediv_q)[T.(3.0, 5.0]]          0.220386  1.246557  1.075844  1.444360
# C(state_top10)[T.CO]                -0.339997  0.711772  0.554149  0.914231
# C(titlediv_q)[T.(5.0, 36.0]]         0.199908  1.221291  1.041636  1.431931
# C(cat_top10)[T.games_video]          0.192562  1.212351  1.035334  1.419634
# C(state_top10)[T.MA]                -0.168321  0.845083  0.735238  0.971338
# C(tempo_q)[T.(13.0, 26.0]]           0.372177  1.450890  1.060346  1.985279
# C(cat_top10)[T.ecommerce]            0.151085  1.163095  0.997320  1.356427
# C(tempo_q)[T.(11.0, 13.0]]           0.330954  1.392295  0.991619  1.954869
# C(state_top10)[T.WA]                -0.120444  0.886526  0.732405  1.073080
# C(tempo_q)[T.(26.0, 136.0]]         -0.140412  0.869000  0.623768  1.210645
# C(cat_top10)[T.biotech]              0.041228  1.042090  0.922577  1.177084
# C(cat_top10)[T.hardware]             0.045027  1.046057  0.859687  1.272829
# C(tempo_q)[T.Unknown]               -0.035978  0.964662  0.769632  1.209113
# C(titlediv_q)[T.Unknown]            -0.013742  0.986352  0.897071  1.084518
# C(cat_top10)[T.cleantech]            0.008168  1.008201  0.829505  1.225394
#
#                                         p_value 결론(alpha=0.05)
# log_rel_z                         1.905341e-266      [귀무가설 기각]
# Intercept                          4.833364e-34      [귀무가설 기각]
# C(state_top10)[T.Others]           1.036392e-33      [귀무가설 기각]
# is_obj_funding_total_usd_private   1.873352e-23      [귀무가설 기각]
# C(state_top10)[T.Unknown]          1.803399e-22      [귀무가설 기각]
# C(cat_top10)[T.web]                1.032840e-08      [귀무가설 기각]
# C(cat_top10)[T.software]           2.581633e-07      [귀무가설 기각]
# C(state_top10)[T.PA]               5.468317e-07      [귀무가설 기각]
# C(state_top10)[T.FL]               1.257499e-05      [귀무가설 기각]
# C(cat_top10)[T.enterprise]         1.035080e-04      [귀무가설 기각]
# C(state_top10)[T.NY]               1.487017e-04      [귀무가설 기각]
# C(state_top10)[T.IL]               1.886584e-04      [귀무가설 기각]
# C(state_top10)[T.TX]               2.071331e-04      [귀무가설 기각]
# C(cat_top10)[T.advertising]        4.861037e-04      [귀무가설 기각]
# C(cat_top10)[T.mobile]             5.171771e-04      [귀무가설 기각]
# C(titlediv_q)[T.(3.0, 5.0]]        3.358907e-03      [귀무가설 기각]
# C(state_top10)[T.CO]               7.766192e-03      [귀무가설 기각]
# C(titlediv_q)[T.(5.0, 36.0]]       1.379953e-02      [귀무가설 기각]
# C(cat_top10)[T.games_video]        1.679533e-02      [귀무가설 기각]
# C(state_top10)[T.MA]               1.782155e-02      [귀무가설 기각]
# C(tempo_q)[T.(13.0, 26.0]]         2.000798e-02      [귀무가설 기각]
# C(cat_top10)[T.ecommerce]          5.413507e-02   [귀무가설 기각 못함]
# C(tempo_q)[T.(11.0, 13.0]]         5.595838e-02   [귀무가설 기각 못함]
# C(state_top10)[T.WA]               2.164215e-01   [귀무가설 기각 못함]
# C(tempo_q)[T.(26.0, 136.0]]        4.065341e-01   [귀무가설 기각 못함]
# C(cat_top10)[T.biotech]            5.071011e-01   [귀무가설 기각 못함]
# C(cat_top10)[T.hardware]           6.528741e-01   [귀무가설 기각 못함]
# C(tempo_q)[T.Unknown]              7.548866e-01   [귀무가설 기각 못함]
# C(titlediv_q)[T.Unknown]           7.764960e-01   [귀무가설 기각 못함]
# C(cat_top10)[T.cleantech]          9.346015e-01   [귀무가설 기각 못함]

# %% [markdown]
# ### Model B

# %% [markdown]
# <span style = "font-size: 15px;">
# Model B: 창업자 특성이 성공률에 미치는 영향<br>
# 창업자 특성: 학력, 전공, 학교, 창업경험, 마일스톤<br>
# → “창업자 변수들이 결측이 많더라도 표본을 버리지 않도록” bin/Unknown을 사용<br>
# </span>
#
# <span style = "font-size : 13px;">
# * “창업자 특성의 순수 효과”를 보려면, 스타트업 규모/네트워크(relationships) 같은 교란을 일부 통제하는 편이 합리적<br>
# * “창업자 정보만으로 설명력”을 보려면 통제를 빼는 변형도 가능<br>
# </span>

# %%
terms_B = ["log_rel_z"]  # (선택) 관계규모를 통제변수로 두고 창업자 영향만 보려면 포함
# 통제 제외하고 싶으면 위 줄을 지우세요.

if "degree_cat" in df_s.columns:
    terms_B.append("C(degree_cat)")
if "stem_q" in df_s.columns:
    terms_B.append("C(stem_q)")
if "topuni_q" in df_s.columns:
    terms_B.append("C(topuni_q)")
if "founding_bin" in df_s.columns:
    terms_B.append("C(founding_bin)")

formula_B = "success_flag ~ " + " + ".join(terms_B)

mB = fit_logit(df_s, formula_B)
tab_B = or_table(mB, alpha=ALPHA)

print(mB.summary())
tab_B.head(40)
# Out:
# [경고] HC1 robust SE 계산 실패 → nonrobust SE로 진행합니다.
# 원인: AttributeError 'GLMResults' object has no attribute 'get_robustcov_results'
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           success_flag   No. Observations:                31707
# Model:                            GLM   Df Residuals:                    31695
# Model Family:                Binomial   Df Model:                           11
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -13033.
# Date:                    월, 19 1 2026   Deviance:                       26067.
# Time:                        09:50:19   Pearson chi2:                 3.24e+04
# No. Iterations:                   100   Pseudo R-squ. (CS):            0.07798
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -2.1187      0.303     -6.992      0.000      -2.713      -1.525
# C(degree_cat)[T.1]             0.6306      0.456      1.383      0.167      -0.263       1.524
# C(degree_cat)[T.2]             0.3386      0.309      1.096      0.273      -0.267       0.944
# C(degree_cat)[T.3]             0.4636      0.308      1.507      0.132      -0.139       1.067
# C(degree_cat)[T.4]             0.3022      0.319      0.948      0.343      -0.322       0.927
# C(degree_cat)[T.Unknown]       0.4004      0.305      1.313      0.189      -0.197       0.998
# C(stem_q)[T.(0.5, 1.0]]       -0.0398      0.089     -0.448      0.654      -0.214       0.134
# C(stem_q)[T.Unknown]          -0.0346      0.016     -2.101      0.036      -0.067      -0.002
# C(topuni_q)[T.Unknown]        -0.0346      0.016     -2.101      0.036      -0.067      -0.002
# C(founding_bin)[T.2]           0.1737      0.078      2.225      0.026       0.021       0.327
# C(founding_bin)[T.3-4]         0.0839      0.104      0.809      0.419      -0.119       0.287
# C(founding_bin)[T.5+]          0.1174      0.194      0.606      0.545      -0.263       0.497
# C(founding_bin)[T.Unknown]    -0.0346      0.016     -2.101      0.036      -0.067      -0.002
# log_rel_z                      0.7618      0.017     44.991      0.000       0.729       0.795
# ==============================================================================================
#                             coef(logit)        OR    CI_low   CI_high  \
# log_rel_z                      0.761829  2.142191  2.072263  2.214479
# Intercept                     -2.118664  0.120192  0.066369  0.217665
# C(founding_bin)[T.2]           0.173659  1.189650  1.020919  1.386268
# C(stem_q)[T.Unknown]          -0.034633  0.965959  0.935248  0.997679
# C(founding_bin)[T.Unknown]    -0.034633  0.965959  0.935248  0.997679
# C(topuni_q)[T.Unknown]        -0.034633  0.965959  0.935248  0.997679
# C(degree_cat)[T.3]             0.463645  1.589858  0.869875  2.905761
# C(degree_cat)[T.1]             0.630634  1.878802  0.768774  4.591592
# C(degree_cat)[T.Unknown]       0.400364  1.492368  0.820843  2.713261
# C(degree_cat)[T.2]             0.338635  1.403031  0.765809  2.570482
# C(degree_cat)[T.4]             0.302163  1.352781  0.724461  2.526041
# C(founding_bin)[T.3-4]         0.083921  1.087543  0.887403  1.332821
# C(founding_bin)[T.5+]          0.117398  1.124567  0.769063  1.644405
# C(stem_q)[T.(0.5, 1.0]]       -0.039767  0.961014  0.807587  1.143589
#
#                                  p_value 결론(alpha=0.05)
# log_rel_z                   0.000000e+00      [귀무가설 기각]
# Intercept                   2.704099e-12      [귀무가설 기각]
# C(founding_bin)[T.2]        2.606449e-02      [귀무가설 기각]
# C(stem_q)[T.Unknown]        3.564971e-02      [귀무가설 기각]
# C(founding_bin)[T.Unknown]  3.564971e-02      [귀무가설 기각]
# C(topuni_q)[T.Unknown]      3.564971e-02      [귀무가설 기각]
# C(degree_cat)[T.3]          1.318404e-01   [귀무가설 기각 못함]
# C(degree_cat)[T.1]          1.666024e-01   [귀무가설 기각 못함]
# C(degree_cat)[T.Unknown]    1.892932e-01   [귀무가설 기각 못함]
# C(degree_cat)[T.2]          2.729845e-01   [귀무가설 기각 못함]
# C(degree_cat)[T.4]          3.429573e-01   [귀무가설 기각 못함]
# C(founding_bin)[T.3-4]      4.186571e-01   [귀무가설 기각 못함]
# C(founding_bin)[T.5+]       5.448166e-01   [귀무가설 기각 못함]
# C(stem_q)[T.(0.5, 1.0]]     6.540824e-01   [귀무가설 기각 못함]

# %%
terms_B = []  

if "degree_cat" in df_s.columns:
    terms_B.append("C(degree_cat)")
if "stem_q" in df_s.columns:
    terms_B.append("C(stem_q)")
if "topuni_q" in df_s.columns:
    terms_B.append("C(topuni_q)")
if "founding_bin" in df_s.columns:
    terms_B.append("C(founding_bin)")

formula_B = "success_flag ~ " + " + ".join(terms_B)

mB = fit_logit(df_s, formula_B)
tab_B = or_table(mB, alpha=ALPHA)

print(mB.summary())
tab_B.head(40)
# Out:
# [경고] HC1 robust SE 계산 실패 → nonrobust SE로 진행합니다.
# 원인: AttributeError 'GLMResults' object has no attribute 'get_robustcov_results'
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           success_flag   No. Observations:                31707
# Model:                            GLM   Df Residuals:                    31696
# Model Family:                Binomial   Df Model:                           10
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -14136.
# Date:                    월, 19 1 2026   Deviance:                       28272.
# Time:                        10:34:15   Pearson chi2:                 3.15e+04
# No. Iterations:                   100   Pseudo R-squ. (CS):            0.01157
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# Intercept                     -1.6704      0.297     -5.631      0.000      -2.252      -1.089
# C(degree_cat)[T.1]             0.7838      0.437      1.794      0.073      -0.072       1.640
# C(degree_cat)[T.2]             0.5158      0.302      1.708      0.088      -0.076       1.108
# C(degree_cat)[T.3]             0.6375      0.301      2.117      0.034       0.047       1.228
# C(degree_cat)[T.4]             0.6696      0.311      2.150      0.032       0.059       1.280
# C(degree_cat)[T.Unknown]       0.3338      0.301      1.107      0.268      -0.257       0.925
# C(stem_q)[T.(0.5, 1.0]]        0.0361      0.084      0.429      0.668      -0.129       0.201
# C(stem_q)[T.Unknown]       -1.505e+11   3.35e+11     -0.449      0.654   -8.08e+11    5.07e+11
# C(topuni_q)[T.Unknown]      7.537e+10   1.68e+11      0.449      0.654   -2.54e+11    4.05e+11
# C(founding_bin)[T.2]           0.2193      0.075      2.936      0.003       0.073       0.366
# C(founding_bin)[T.3-4]         0.1658      0.099      1.676      0.094      -0.028       0.360
# C(founding_bin)[T.5+]          0.2683      0.185      1.450      0.147      -0.094       0.631
# C(founding_bin)[T.Unknown]  7.512e+10   1.67e+11      0.449      0.654   -2.53e+11    4.03e+11
# ==============================================================================================
#                              coef(logit)        OR    CI_low   CI_high  \
# Intercept                  -1.670422e+00  0.188168  0.105206  0.336551
# C(founding_bin)[T.2]        2.193479e-01  1.245264  1.075624  1.441660
# C(degree_cat)[T.4]          6.696323e-01  1.953519  1.061025  3.596746
# C(degree_cat)[T.3]          6.375393e-01  1.891820  1.048282  3.414142
# C(degree_cat)[T.1]          7.837737e-01  2.189720  0.930082  5.155323
# C(degree_cat)[T.2]          5.157644e-01  1.674918  0.926748  3.027092
# C(founding_bin)[T.3-4]      1.658141e-01  1.180354  0.972296  1.432933
# C(founding_bin)[T.5+]       2.682847e-01  1.307719  0.909959  1.879348
# C(degree_cat)[T.Unknown]    3.337826e-01  1.396240  0.773341  2.520862
# C(stem_q)[T.Unknown]       -1.504881e+11  0.000000  0.000000       inf
# C(topuni_q)[T.Unknown]      7.536617e+10       inf  0.000000       inf
# C(founding_bin)[T.Unknown]  7.512193e+10       inf  0.000000       inf
# C(stem_q)[T.(0.5, 1.0]]     3.608616e-02  1.036745  0.879110  1.222646
#
#                                  p_value 결론(alpha=0.05)
# Intercept                   1.791476e-08      [귀무가설 기각]
# C(founding_bin)[T.2]        3.328736e-03      [귀무가설 기각]
# C(degree_cat)[T.4]          3.154210e-02      [귀무가설 기각]
# C(degree_cat)[T.3]          3.430230e-02      [귀무가설 기각]
# C(degree_cat)[T.1]          7.280481e-02   [귀무가설 기각 못함]
# C(degree_cat)[T.2]          8.763001e-02   [귀무가설 기각 못함]
# C(founding_bin)[T.3-4]      9.374058e-02   [귀무가설 기각 못함]
# C(founding_bin)[T.5+]       1.470587e-01   [귀무가설 기각 못함]
# C(degree_cat)[T.Unknown]    2.681724e-01   [귀무가설 기각 못함]
# C(stem_q)[T.Unknown]        6.536019e-01   [귀무가설 기각 못함]
# C(topuni_q)[T.Unknown]      6.536019e-01   [귀무가설 기각 못함]
# C(founding_bin)[T.Unknown]  6.536019e-01   [귀무가설 기각 못함]
# C(stem_q)[T.(0.5, 1.0]]     6.680457e-01   [귀무가설 기각 못함]

# %% [markdown]
# ### Model C

# %% [markdown]
# <span style = "font-size: 15px">
# Model C: 스타트업 + 창업자의 상호작용(시너지)<br>
# </span>
# <span style="font-size: 13px;">
# <b>시너지의 통계적 정의</b><br>
# * “함께 적용될 때 더 큰 시너지”는 회귀에서 상호작용항(interaction) 으로 정의하는 것이 표준<br>
# </span>

# %%
# A 확장 + B 변수를 모두 포함(상호작용 없이)
terms_C_base = [
    "C(cat_top10)",
    "C(state_top10)",
    "is_obj_funding_total_usd_private",
    "log_rel_z",
]

if "tempo_q" in df_s.columns:
    terms_C_base.append("C(tempo_q)")
if "titlediv_q" in df_s.columns:
    terms_C_base.append("C(titlediv_q)")

if "degree_cat" in df_s.columns:
    terms_C_base.append("C(degree_cat)")
if "stem_q" in df_s.columns:
    terms_C_base.append("C(stem_q)")
if "topuni_q" in df_s.columns:
    terms_C_base.append("C(topuni_q)")
if "founding_bin" in df_s.columns:
    terms_C_base.append("C(founding_bin)")

formula_C_base = "success_flag ~ " + " + ".join(terms_C_base)

mC_base = fit_logit(df_s, formula_C_base)
tab_C_base = or_table(mC_base, alpha=ALPHA)
tab_C_base.head(40)
# Out:
# [경고] HC1 robust SE 계산 실패 → nonrobust SE로 진행합니다.
# 원인: AttributeError 'GLMResults' object has no attribute 'get_robustcov_results'
#                                    coef(logit)        OR    CI_low   CI_high  \
# log_rel_z                         6.610129e-01  1.936753  1.866096  2.010085
# C(state_top10)[T.Others]         -6.404601e-01  0.527050  0.475089  0.584693
# is_obj_funding_total_usd_private -6.269736e-01  0.534206  0.471534  0.605208
# C(state_top10)[T.Unknown]        -4.131018e-01  0.661595  0.608987  0.718748
# Intercept                        -1.925611e+00  0.145787  0.075693  0.280788
# C(cat_top10)[T.web]               3.293966e-01  1.390129  1.240442  1.557880
# C(cat_top10)[T.software]          2.444320e-01  1.276896  1.163245  1.401651
# C(state_top10)[T.PA]             -7.226078e-01  0.485485  0.366641  0.642851
# C(state_top10)[T.FL]             -6.423553e-01  0.526052  0.396414  0.698085
# C(cat_top10)[T.enterprise]        2.705787e-01  1.310723  1.142438  1.503797
# C(state_top10)[T.NY]             -2.456865e-01  0.782167  0.689939  0.886724
# C(state_top10)[T.IL]             -5.145167e-01  0.597789  0.458353  0.779644
# C(state_top10)[T.TX]             -3.657544e-01  0.693673  0.572865  0.839958
# C(cat_top10)[T.mobile]            2.270684e-01  1.254916  1.103413  1.427221
# C(cat_top10)[T.advertising]       2.697255e-01  1.309605  1.122201  1.528304
# C(titlediv_q)[T.(3.0, 5.0]]       2.570849e-01  1.293155  1.091144  1.532565
# C(state_top10)[T.CO]             -3.405505e-01  0.711379  0.554243  0.913065
# C(titlediv_q)[T.(5.0, 36.0]]      2.434045e-01  1.275585  1.065377  1.527268
# C(cat_top10)[T.games_video]       1.886376e-01  1.207603  1.031075  1.414354
# C(state_top10)[T.MA]             -1.659225e-01  0.847112  0.736436  0.974421
# C(tempo_q)[T.(13.0, 26.0]]        3.705684e-01  1.448558  1.058967  1.981477
# C(tempo_q)[T.(11.0, 13.0]]        3.274272e-01  1.387394  0.988595  1.947068
# C(cat_top10)[T.ecommerce]         1.478119e-01  1.159295  0.993433  1.352849
# C(founding_bin)[T.2]              1.360270e-01  1.145713  0.979991  1.339459
# C(degree_cat)[T.3]                4.086202e-01  1.504740  0.813490  2.783368
# C(state_top10)[T.WA]             -1.223920e-01  0.884801  0.731307  1.070513
# C(stem_q)[T.(0.5, 1.0]]          -1.139565e-01  0.892297  0.746220  1.066969
# C(degree_cat)[T.Unknown]          3.784854e-01  1.460071  0.793565  2.686370
# C(degree_cat)[T.1]                5.322657e-01  1.702786  0.674310  4.299924
# C(degree_cat)[T.2]                2.771255e-01  1.319332  0.711333  2.447008
# C(tempo_q)[T.(26.0, 136.0]]      -1.409914e-01  0.868497  0.623593  1.209582
# C(degree_cat)[T.4]                2.598948e-01  1.296794  0.685141  2.454494
# C(cat_top10)[T.biotech]           4.535172e-02  1.046396  0.925869  1.182612
# C(titlediv_q)[T.Unknown]         -3.046115e+12  0.000000  0.000000       inf
# C(topuni_q)[T.Unknown]            1.067817e+12       inf  0.000000       inf
# C(stem_q)[T.Unknown]              1.067817e+12       inf  0.000000       inf
# C(founding_bin)[T.Unknown]        9.104804e+11       inf  0.000000       inf
# C(cat_top10)[T.hardware]          4.687725e-02  1.047993  0.861247  1.275232
# C(tempo_q)[T.Unknown]            -3.795573e-02  0.962756  0.768816  1.205617
# C(founding_bin)[T.3-4]            2.448993e-02  1.024792  0.831220  1.263444
#
#                                         p_value 결론(alpha=0.05)
# log_rel_z                         2.958087e-266      [귀무가설 기각]
# C(state_top10)[T.Others]           1.134002e-33      [귀무가설 기각]
# is_obj_funding_total_usd_private   7.046194e-23      [귀무가설 기각]
# C(state_top10)[T.Unknown]          1.487583e-22      [귀무가설 기각]
# Intercept                          8.510558e-09      [귀무가설 기각]
# C(cat_top10)[T.web]                1.455499e-08      [귀무가설 기각]
# C(cat_top10)[T.software]           2.757701e-07      [귀무가설 기각]
# C(state_top10)[T.PA]               4.550037e-07      [귀무가설 기각]
# C(state_top10)[T.FL]               8.600024e-06      [귀무가설 기각]
# C(cat_top10)[T.enterprise]         1.137073e-04      [귀무가설 기각]
# C(state_top10)[T.NY]               1.240304e-04      [귀무가설 기각]
# C(state_top10)[T.IL]               1.465592e-04      [귀무가설 기각]
# C(state_top10)[T.TX]               1.794374e-04      [귀무가설 기각]
# C(cat_top10)[T.mobile]             5.420519e-04      [귀무가설 기각]
# C(cat_top10)[T.advertising]        6.189358e-04      [귀무가설 기각]
# C(titlediv_q)[T.(3.0, 5.0]]        3.012452e-03      [귀무가설 기각]
# C(state_top10)[T.CO]               7.492570e-03      [귀무가설 기각]
# C(titlediv_q)[T.(5.0, 36.0]]       8.067414e-03      [귀무가설 기각]
# C(cat_top10)[T.games_video]        1.930985e-02      [귀무가설 기각]
# C(state_top10)[T.MA]               2.019539e-02      [귀무가설 기각]
# C(tempo_q)[T.(13.0, 26.0]]         2.042653e-02      [귀무가설 기각]
# C(tempo_q)[T.(11.0, 13.0]]         5.827445e-02   [귀무가설 기각 못함]
# C(cat_top10)[T.ecommerce]          6.061097e-02   [귀무가설 기각 못함]
# C(founding_bin)[T.2]               8.793035e-02   [귀무가설 기각 못함]
# C(degree_cat)[T.3]                 1.928625e-01   [귀무가설 기각 못함]
# C(state_top10)[T.WA]               2.080188e-01   [귀무가설 기각 못함]
# C(stem_q)[T.(0.5, 1.0]]            2.115489e-01   [귀무가설 기각 못함]
# C(degree_cat)[T.Unknown]           2.237252e-01   [귀무가설 기각 못함]
# C(degree_cat)[T.1]                 2.600869e-01   [귀무가설 기각 못함]
# C(degree_cat)[T.2]                 3.792589e-01   [귀무가설 기각 못함]
# C(tempo_q)[T.(26.0, 136.0]]        4.041753e-01   [귀무가설 기각 못함]
# C(degree_cat)[T.4]                 4.246526e-01   [귀무가설 기각 못함]
# C(cat_top10)[T.biotech]            4.676181e-01   [귀무가설 기각 못함]
# C(titlediv_q)[T.Unknown]           5.785913e-01   [귀무가설 기각 못함]
# C(topuni_q)[T.Unknown]             5.785913e-01   [귀무가설 기각 못함]
# C(stem_q)[T.Unknown]               5.785913e-01   [귀무가설 기각 못함]
# C(founding_bin)[T.Unknown]         5.785913e-01   [귀무가설 기각 못함]
# C(cat_top10)[T.hardware]           6.396667e-01   [귀무가설 기각 못함]
# C(tempo_q)[T.Unknown]              7.408651e-01   [귀무가설 기각 못함]
# C(founding_bin)[T.3-4]             8.186539e-01   [귀무가설 기각 못함]

# %% [markdown]
# <span style = "font-size: 15px;">
# 시너지 후보(상호작용) 3개부터 시작: 과적합/폭발 방지<br>
# </span>
# <span style = "font-size: 13px;">
# * 산업(Top10) × 학력(6범주) 같은 상호작용을 한 번에 넣으면 파라미터가 급증하고 희소셀로 불안정해질 수 있음<br>
# * “가설적으로 가장 의미 있는” 상호작용부터 소수만 넣고, 우도비(LR) 검정으로 추가 효용을 확인<br>
# </span>

# %%
from scipy import stats

def lr_test(m_small, m_big):
    # GLM은 llf 제공
    LR = 2 * (m_big.llf - m_small.llf)
    df = m_big.df_model - m_small.df_model
    p = stats.chi2.sf(LR, df)
    return LR, df, p

# 상호작용 포함 모델
interaction_terms = [
    "is_obj_funding_total_usd_private:C(topuni_q)" if "topuni_q" in df_s.columns else None,
    "is_obj_funding_total_usd_private:C(degree_cat)" if "degree_cat" in df_s.columns else None,
    "log_rel_z:C(founding_bin)" if "founding_bin" in df_s.columns else None,
]
interaction_terms = [t for t in interaction_terms if t is not None]

formula_C_int = formula_C_base + " + " + " + ".join(interaction_terms)

mC_int = fit_logit(df_s, formula_C_int)
tab_C_int = or_table(mC_int, alpha=ALPHA)

LR, ddf, p_lr = lr_test(mC_base, mC_int)
print(f"[LR test] base vs interaction: LR={LR:.3f}, df={ddf}, p={p_lr:.4g}")

tab_C_int.head(60)

# LR-test p < 0.05이면: “상호작용(시너지) 추가”가 모델 적합을 유의미하게 개선
# 상호작용항 개별 p-value가 유의하면: 어떤 조합이 시너지를 만드는지 OR로 보고 가능
# Out:
# [경고] HC1 robust SE 계산 실패 → nonrobust SE로 진행합니다.
# 원인: AttributeError 'GLMResults' object has no attribute 'get_robustcov_results'
# [LR test] base vs interaction: LR=12.092, df=9, p=0.2082
#                                                             coef(logit)  \
# C(state_top10)[T.Others]                                  -6.394836e-01
# C(state_top10)[T.Unknown]                                 -4.156796e-01
# log_rel_z                                                  6.237438e-01
# Intercept                                                 -2.016057e+00
# C(cat_top10)[T.web]                                        3.265161e-01
# C(cat_top10)[T.software]                                   2.458671e-01
# C(state_top10)[T.PA]                                      -7.214448e-01
# C(state_top10)[T.FL]                                      -6.419825e-01
# C(cat_top10)[T.enterprise]                                 2.703375e-01
# C(state_top10)[T.NY]                                      -2.471599e-01
# C(state_top10)[T.IL]                                      -5.188190e-01
# C(state_top10)[T.TX]                                      -3.664245e-01
# C(cat_top10)[T.mobile]                                     2.277451e-01
# C(cat_top10)[T.advertising]                                2.700301e-01
# C(state_top10)[T.CO]                                      -3.402439e-01
# C(titlediv_q)[T.(3.0, 5.0]]                                2.436046e-01
# C(cat_top10)[T.games_video]                                1.871233e-01
# C(state_top10)[T.MA]                                      -1.642773e-01
# C(tempo_q)[T.(13.0, 26.0]]                                 3.694305e-01
# is_obj_funding_total_usd_private:C(topuni_q)[T.Unknown]    4.155800e-01
# is_obj_funding_total_usd_private:C(degree_cat)[T.Unknown] -1.877652e+00
# is_obj_funding_total_usd_private:C(degree_cat)[T.2]       -1.858335e+00
# C(tempo_q)[T.(11.0, 13.0]]                                 3.283989e-01
# C(cat_top10)[T.ecommerce]                                  1.458144e-01
# C(titlediv_q)[T.(5.0, 36.0]]                               2.323320e-01
# is_obj_funding_total_usd_private:C(degree_cat)[T.1]       -1.761255e-16
# C(degree_cat)[T.Unknown]                                   5.424888e-01
# C(degree_cat)[T.3]                                         5.440109e-01
# is_obj_funding_total_usd_private:C(degree_cat)[T.3]       -1.445555e+00
# C(degree_cat)[T.1]                                         6.760237e-01
# C(degree_cat)[T.2]                                         4.374466e-01
# C(stem_q)[T.(0.5, 1.0]]                                   -1.170443e-01
# C(state_top10)[T.WA]                                      -1.251781e-01
# is_obj_funding_total_usd_private:C(degree_cat)[T.4]       -1.239672e+00
# log_rel_z:C(founding_bin)[T.3-4]                           1.530367e-01
# C(titlediv_q)[T.Unknown]                                  -1.980976e-02
# C(founding_bin)[T.Unknown]                                -1.980976e-02
# C(topuni_q)[T.Unknown]                                    -1.980976e-02
# C(stem_q)[T.Unknown]                                      -1.980976e-02
# C(degree_cat)[T.4]                                         3.857623e-01
# is_obj_funding_total_usd_private                           9.052874e-01
# C(founding_bin)[T.2]                                       1.139961e-01
# C(cat_top10)[T.biotech]                                    5.095774e-02
# C(tempo_q)[T.(26.0, 136.0]]                               -1.355148e-01
# C(founding_bin)[T.3-4]                                    -1.310778e-01
# C(founding_bin)[T.5+]                                      2.147052e-01
# log_rel_z:C(founding_bin)[T.5+]                           -1.479405e-01
# C(cat_top10)[T.hardware]                                   5.023517e-02
# log_rel_z:C(founding_bin)[T.Unknown]                       3.904651e-02
# C(tempo_q)[T.Unknown]                                     -3.724054e-02
# log_rel_z:C(founding_bin)[T.2]                             2.839644e-02
# C(cat_top10)[T.cleantech]                                  1.500526e-02
#
#                                                                  OR    CI_low  \
# C(state_top10)[T.Others]                                   0.527565  0.475701
# C(state_top10)[T.Unknown]                                  0.659892  0.607461
# log_rel_z                                                  1.865901  1.608215
# Intercept                                                  0.133180  0.066908
# C(cat_top10)[T.web]                                        1.386130  1.236761
# C(cat_top10)[T.software]                                   1.278730  1.165062
# C(state_top10)[T.PA]                                       0.486050  0.365888
# C(state_top10)[T.FL]                                       0.526248  0.395396
# C(cat_top10)[T.enterprise]                                 1.310407  1.143036
# C(state_top10)[T.NY]                                       0.781016  0.688870
# C(state_top10)[T.IL]                                       0.595223  0.455385
# C(state_top10)[T.TX]                                       0.693208  0.572227
# C(cat_top10)[T.mobile]                                     1.255765  1.104795
# C(cat_top10)[T.advertising]                                1.310004  1.123553
# C(state_top10)[T.CO]                                       0.711597  0.554119
# C(titlediv_q)[T.(3.0, 5.0]]                                1.275840  1.060147
# C(cat_top10)[T.games_video]                                1.205776  1.029423
# C(state_top10)[T.MA]                                       0.848507  0.738064
# C(tempo_q)[T.(13.0, 26.0]]                                 1.446910  1.056995
# is_obj_funding_total_usd_private:C(topuni_q)[T.Unknown]    1.515249  1.057507
# is_obj_funding_total_usd_private:C(degree_cat)[T.Unknown]  0.152949  0.026151
# is_obj_funding_total_usd_private:C(degree_cat)[T.2]        0.155932  0.024908
# C(tempo_q)[T.(11.0, 13.0]]                                 1.388743  0.988499
# C(cat_top10)[T.ecommerce]                                  1.156981  0.991718
# C(titlediv_q)[T.(5.0, 36.0]]                               1.261538  0.976361
# is_obj_funding_total_usd_private:C(degree_cat)[T.1]        1.000000  1.000000
# C(degree_cat)[T.Unknown]                                   1.720283  0.900475
# C(degree_cat)[T.3]                                         1.722903  0.897074
# is_obj_funding_total_usd_private:C(degree_cat)[T.3]        0.235615  0.038908
# C(degree_cat)[T.1]                                         1.966045  0.767511
# C(degree_cat)[T.2]                                         1.548748  0.804243
# C(stem_q)[T.(0.5, 1.0]]                                    0.889546  0.744767
# C(state_top10)[T.WA]                                       0.882340  0.728747
# is_obj_funding_total_usd_private:C(degree_cat)[T.4]        0.289479  0.041899
# log_rel_z:C(founding_bin)[T.3-4]                           1.165368  0.912334
# C(titlediv_q)[T.Unknown]                                   0.980385  0.949478
# C(founding_bin)[T.Unknown]                                 0.980385  0.949478
# C(topuni_q)[T.Unknown]                                     0.980385  0.949478
# C(stem_q)[T.Unknown]                                       0.980385  0.949478
# C(degree_cat)[T.4]                                         1.470735  0.748652
# is_obj_funding_total_usd_private                           2.472642  0.435689
# C(founding_bin)[T.2]                                       1.120748  0.887028
# C(cat_top10)[T.biotech]                                    1.052278  0.930683
# C(tempo_q)[T.(26.0, 136.0]]                                0.873266  0.626176
# C(founding_bin)[T.3-4]                                     0.877149  0.632829
# C(founding_bin)[T.5+]                                      1.239496  0.655130
# log_rel_z:C(founding_bin)[T.5+]                            0.862482  0.542274
# C(cat_top10)[T.hardware]                                   1.051518  0.864452
# log_rel_z:C(founding_bin)[T.Unknown]                       1.039819  0.892539
# C(tempo_q)[T.Unknown]                                      0.963444  0.768838
# log_rel_z:C(founding_bin)[T.2]                             1.028803  0.849231
# C(cat_top10)[T.cleantech]                                  1.015118  0.835492
#
#                                                              CI_high  \
# C(state_top10)[T.Others]                                    0.585083
# C(state_top10)[T.Unknown]                                   0.716847
# log_rel_z                                                   2.164876
# Intercept                                                   0.265091
# C(cat_top10)[T.web]                                         1.553540
# C(cat_top10)[T.software]                                    1.403487
# C(state_top10)[T.PA]                                        0.645674
# C(state_top10)[T.FL]                                        0.700404
# C(cat_top10)[T.enterprise]                                  1.502285
# C(state_top10)[T.NY]                                        0.885487
# C(state_top10)[T.IL]                                        0.778002
# C(state_top10)[T.TX]                                        0.839769
# C(cat_top10)[T.mobile]                                      1.427365
# C(cat_top10)[T.advertising]                                 1.527396
# C(state_top10)[T.CO]                                        0.913830
# C(titlediv_q)[T.(3.0, 5.0]]                                 1.535417
# C(cat_top10)[T.games_video]                                 1.412340
# C(state_top10)[T.MA]                                        0.975476
# C(tempo_q)[T.(13.0, 26.0]]                                  1.980661
# is_obj_funding_total_usd_private:C(topuni_q)[T.Unknown]     2.171125
# is_obj_funding_total_usd_private:C(degree_cat)[T.Unknown]   0.894535
# is_obj_funding_total_usd_private:C(degree_cat)[T.2]         0.976194
# C(tempo_q)[T.(11.0, 13.0]]                                  1.951045
# C(cat_top10)[T.ecommerce]                                   1.349785
# C(titlediv_q)[T.(5.0, 36.0]]                                1.630012
# is_obj_funding_total_usd_private:C(degree_cat)[T.1]         1.000000
# C(degree_cat)[T.Unknown]                                    3.286460
# C(degree_cat)[T.3]                                          3.308976
# is_obj_funding_total_usd_private:C(degree_cat)[T.3]         1.426822
# C(degree_cat)[T.1]                                          5.036188
# C(degree_cat)[T.2]                                          2.982457
# C(stem_q)[T.(0.5, 1.0]]                                     1.062468
# C(state_top10)[T.WA]                                        1.068303
# is_obj_funding_total_usd_private:C(degree_cat)[T.4]         1.999983
# log_rel_z:C(founding_bin)[T.3-4]                            1.488579
# C(titlediv_q)[T.Unknown]                                    1.012299
# C(founding_bin)[T.Unknown]                                  1.012299
# C(topuni_q)[T.Unknown]                                      1.012299
# C(stem_q)[T.Unknown]                                        1.012299
# C(degree_cat)[T.4]                                          2.889276
# is_obj_funding_total_usd_private                           14.032847
# C(founding_bin)[T.2]                                        1.416050
# C(cat_top10)[T.biotech]                                     1.189761
# C(tempo_q)[T.(26.0, 136.0]]                                 1.217859
# C(founding_bin)[T.3-4]                                      1.215797
# C(founding_bin)[T.5+]                                       2.345108
# log_rel_z:C(founding_bin)[T.5+]                             1.371771
# C(cat_top10)[T.hardware]                                    1.279066
# log_rel_z:C(founding_bin)[T.Unknown]                        1.211402
# C(tempo_q)[T.Unknown]                                       1.207309
# log_rel_z:C(founding_bin)[T.2]                              1.246347
# C(cat_top10)[T.cleantech]                                   1.233363
#
#                                                                 p_value  \
# C(state_top10)[T.Others]                                   9.144606e-34
# C(state_top10)[T.Unknown]                                  7.489041e-23
# log_rel_z                                                  1.938526e-16
# Intercept                                                  9.457217e-09
# C(cat_top10)[T.web]                                        1.991907e-08
# C(cat_top10)[T.software]                                   2.261212e-07
# C(state_top10)[T.PA]                                       6.385459e-07
# C(state_top10)[T.FL]                                       1.076074e-05
# C(cat_top10)[T.enterprise]                                 1.055611e-04
# C(state_top10)[T.NY]                                       1.140185e-04
# C(state_top10)[T.IL]                                       1.463300e-04
# C(state_top10)[T.TX]                                       1.807524e-04
# C(cat_top10)[T.mobile]                                     4.922036e-04
# C(cat_top10)[T.advertising]                                5.666064e-04
# C(state_top10)[T.CO]                                       7.674881e-03
# C(titlediv_q)[T.(3.0, 5.0]]                                9.934649e-03
# C(cat_top10)[T.games_video]                                2.037327e-02
# C(state_top10)[T.MA]                                       2.094666e-02
# C(tempo_q)[T.(13.0, 26.0]]                                 2.111306e-02
# is_obj_funding_total_usd_private:C(topuni_q)[T.Unknown]    2.353328e-02
# is_obj_funding_total_usd_private:C(degree_cat)[T.Unknown]  3.719268e-02
# is_obj_funding_total_usd_private:C(degree_cat)[T.2]        4.706556e-02
# C(tempo_q)[T.(11.0, 13.0]]                                 5.832118e-02
# C(cat_top10)[T.ecommerce]                                  6.370941e-02
# C(titlediv_q)[T.(5.0, 36.0]]                               7.557040e-02
# is_obj_funding_total_usd_private:C(degree_cat)[T.1]        8.695081e-02
# C(degree_cat)[T.Unknown]                                   1.004762e-01
# C(degree_cat)[T.3]                                         1.023079e-01
# is_obj_funding_total_usd_private:C(degree_cat)[T.3]        1.156859e-01
# C(degree_cat)[T.1]                                         1.589483e-01
# C(degree_cat)[T.2]                                         1.907458e-01
# C(stem_q)[T.(0.5, 1.0]]                                    1.965660e-01
# C(state_top10)[T.WA]                                       1.995454e-01
# is_obj_funding_total_usd_private:C(degree_cat)[T.4]        2.087218e-01
# log_rel_z:C(founding_bin)[T.3-4]                           2.204456e-01
# C(titlediv_q)[T.Unknown]                                   2.254873e-01
# C(founding_bin)[T.Unknown]                                 2.254873e-01
# C(topuni_q)[T.Unknown]                                     2.254873e-01
# C(stem_q)[T.Unknown]                                       2.254873e-01
# C(degree_cat)[T.4]                                         2.628354e-01
# is_obj_funding_total_usd_private                           3.067747e-01
# C(founding_bin)[T.2]                                       3.394102e-01
# C(cat_top10)[T.biotech]                                    4.160160e-01
# C(tempo_q)[T.(26.0, 136.0]]                                4.245532e-01
# C(founding_bin)[T.3-4]                                     4.313358e-01
# C(founding_bin)[T.5+]                                      5.092728e-01
# log_rel_z:C(founding_bin)[T.5+]                            5.320685e-01
# C(cat_top10)[T.hardware]                                   6.152370e-01
# log_rel_z:C(founding_bin)[T.Unknown]                       6.163203e-01
# C(tempo_q)[T.Unknown]                                      7.463254e-01
# log_rel_z:C(founding_bin)[T.2]                             7.717044e-01
# C(cat_top10)[T.cleantech]                                  8.799589e-01
#
#                                                           결론(alpha=0.05)
# C(state_top10)[T.Others]                                       [귀무가설 기각]
# C(state_top10)[T.Unknown]                                      [귀무가설 기각]
# log_rel_z                                                      [귀무가설 기각]
# Intercept                                                      [귀무가설 기각]
# C(cat_top10)[T.web]                                            [귀무가설 기각]
# C(cat_top10)[T.software]                                       [귀무가설 기각]
# C(state_top10)[T.PA]                                           [귀무가설 기각]
# C(state_top10)[T.FL]                                           [귀무가설 기각]
# C(cat_top10)[T.enterprise]                                     [귀무가설 기각]
# C(state_top10)[T.NY]                                           [귀무가설 기각]
# C(state_top10)[T.IL]                                           [귀무가설 기각]
# C(state_top10)[T.TX]                                           [귀무가설 기각]
# C(cat_top10)[T.mobile]                                         [귀무가설 기각]
# C(cat_top10)[T.advertising]                                    [귀무가설 기각]
# C(state_top10)[T.CO]                                           [귀무가설 기각]
# C(titlediv_q)[T.(3.0, 5.0]]                                    [귀무가설 기각]
# C(cat_top10)[T.games_video]                                    [귀무가설 기각]
# C(state_top10)[T.MA]                                           [귀무가설 기각]
# C(tempo_q)[T.(13.0, 26.0]]                                     [귀무가설 기각]
# is_obj_funding_total_usd_private:C(topuni_q)[T.Unknown]        [귀무가설 기각]
# is_obj_funding_total_usd_private:C(degree_cat)[T.Unknown]      [귀무가설 기각]
# is_obj_funding_total_usd_private:C(degree_cat)[T.2]            [귀무가설 기각]
# C(tempo_q)[T.(11.0, 13.0]]                                  [귀무가설 기각 못함]
# C(cat_top10)[T.ecommerce]                                   [귀무가설 기각 못함]
# C(titlediv_q)[T.(5.0, 36.0]]                                [귀무가설 기각 못함]
# is_obj_funding_total_usd_private:C(degree_cat)[T.1]         [귀무가설 기각 못함]
# C(degree_cat)[T.Unknown]                                    [귀무가설 기각 못함]
# C(degree_cat)[T.3]                                          [귀무가설 기각 못함]
# is_obj_funding_total_usd_private:C(degree_cat)[T.3]         [귀무가설 기각 못함]
# C(degree_cat)[T.1]                                          [귀무가설 기각 못함]
# C(degree_cat)[T.2]                                          [귀무가설 기각 못함]
# C(stem_q)[T.(0.5, 1.0]]                                     [귀무가설 기각 못함]
# C(state_top10)[T.WA]                                        [귀무가설 기각 못함]
# is_obj_funding_total_usd_private:C(degree_cat)[T.4]         [귀무가설 기각 못함]
# log_rel_z:C(founding_bin)[T.3-4]                            [귀무가설 기각 못함]
# C(titlediv_q)[T.Unknown]                                    [귀무가설 기각 못함]
# C(founding_bin)[T.Unknown]                                  [귀무가설 기각 못함]
# C(topuni_q)[T.Unknown]                                      [귀무가설 기각 못함]
# C(stem_q)[T.Unknown]                                        [귀무가설 기각 못함]
# C(degree_cat)[T.4]                                          [귀무가설 기각 못함]
# is_obj_funding_total_usd_private                            [귀무가설 기각 못함]
# C(founding_bin)[T.2]                                        [귀무가설 기각 못함]
# C(cat_top10)[T.biotech]                                     [귀무가설 기각 못함]
# C(tempo_q)[T.(26.0, 136.0]]                                 [귀무가설 기각 못함]
# C(founding_bin)[T.3-4]                                      [귀무가설 기각 못함]
# C(founding_bin)[T.5+]                                       [귀무가설 기각 못함]
# log_rel_z:C(founding_bin)[T.5+]                             [귀무가설 기각 못함]
# C(cat_top10)[T.hardware]                                    [귀무가설 기각 못함]
# log_rel_z:C(founding_bin)[T.Unknown]                        [귀무가설 기각 못함]
# C(tempo_q)[T.Unknown]                                       [귀무가설 기각 못함]
# log_rel_z:C(founding_bin)[T.2]                              [귀무가설 기각 못함]
# C(cat_top10)[T.cleantech]                                   [귀무가설 기각 못함]
