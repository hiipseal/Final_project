# %%
#초기 설정및 시스템 라이브러리
import platform
import warnings

# 데이터 시각화 라이브러리
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
print(platform.system())
warnings.filterwarnings('ignore')

# 행,열,결과값 생략 없이 보기,세팅
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)

# 한글 폰트 설정
pd.set_option("display.float_format","{:.2f}".format)
# OS에 따라 다른 폰트 지정
if platform.system() == 'Darwin':   # macOS
    plt.rcParams['font.family'] = 'AppleGothic'
elif platform.system() == 'Windows':  # Windows
    plt.rcParams['font.family'] = 'Malgun Gothic'
else:  # Linux (예: Colab, Ubuntu)
    plt.rcParams['font.family'] = 'NanumGothic'
# Out:
# Darwin

# %% [markdown]
# # 전처리 파일 불러오기

# %%
peo = pd.read_csv("./data/clean_data/clean_people_final.csv")
rel = pd.read_csv("./data/clean_data/clean_relationships_final.csv")
obj = pd.read_csv("./data/clean_data/clean_objects_final.csv")
frs = pd.read_csv("./data/clean_data/clean_fr_final.csv")
fds = pd.read_csv("./data/clean_data/clean_funds_final.csv")
off = pd.read_csv("./data/clean_data/clean_offices_final.csv")
ipo = pd.read_csv("./data/clean_data/clean_ipos_final.csv")
acq = pd.read_csv("./data/clean_data/clean_acquisitions_final.csv")
deg = pd.read_csv("./data/clean_data/clean_degrees_final.csv")
mil = pd.read_csv("./data/clean_data/clean_milestones_final.csv")
inv = pd.read_csv("./data/clean_data/clean_investments_final.csv")

# %%
peo['people_p_id'].duplicated().sum()
peo
# Out:
#        people_p_id   birthplace affiliation_name birthplace_norm  \
# 0              p:2          NaN        Blue Nile             NaN
# 1              p:3          NaN         Wetpaint             NaN
# 2              p:4          NaN             Zoho             NaN
# 3              p:5          NaN             Zoho             NaN
# 4              p:6  Redding, CA     i/o Ventures     redding, ca
# ...            ...          ...              ...             ...
# 226704    p:268589          NaN     Unaffiliated             NaN
# 226705    p:268590          NaN     Unaffiliated             NaN
# 226706    p:268592          NaN     Unaffiliated             NaN
# 226707    p:268593          NaN     Unaffiliated             NaN
# 226708    p:268597          NaN     Unaffiliated             NaN
#
#        cat_people_birthplace
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4              United States
# ...                      ...
# 226704                   NaN
# 226705                   NaN
# 226706                   NaN
# 226707                   NaN
# 226708                   NaN
#
# [226709 rows x 5 columns]

# %% [markdown]
# # 투자 성공 테이블 - 파생변수
#  - success_flag : 성공 플래그 ✅
#
#  - size_bin : 회사 규모 ✅
#
#  - diff_tot_cur_rel : 관계 변화량
#
#  - reinvest_flag : 재투자 여부 ✅
#
#  - total_invested : 원금 ✅
#
#  - round_tempo_months : 투자템포(개월) ✅
#
#  - time_to_last_round : 첫 투자 -> 마지막 투자 ✅

# %% [markdown]
# # 테이블 별 사용 컬럼 추출

# %%
# 1. 각 테이블별 사용할 컬럼 추출

# relationships 컬럼 추출
rel_use_cols = [
    'relationship_id', 'rel_p_id', 'rel_cf_id',
    'is_past',  # p와 cf 관계가 현재인지 과거인지 (0/1)
    'sequence', # 한 사람에 대해 여러 관계가 있을 때, 관계의 순서/우선순위를 나타내는 인덱스(?)
    'cat_rel_title' 
]

# people 컬럼 추출
peo_use_cols = [
    'people_p_id', 'cat_people_birthplace'
]

# degrees 컬럼 추출
deg_use_cols = [
    'degrees_p_id', 'degree_level'  
    'is_degree_missing',
    'cat_degrees_degree_type',  # 학위 종류
    'cat_degrees_subject',      # 전공
    'institution_normalized',    # 출신 학교
    'graduated_at'
]

# objects 컬럼 추출
obj_use_cols = [
    'objects_cfpr_id',
    'founded_at', 'closed_at',
    'description', 'country_code', 'obj_city_fixed',
    'first_investment_at', 'last_investment_at', 'invested_companies',
    'first_funding_at', 'last_funding_at', 'funding_rounds', 'funding_total_usd',  # funding_rounds : 이 회사가 지금까지 받은 투자 라운드의 수
    'relationships',  # 해당 엔티티가 가진 관계수(관련된 사람 또는 조직)
    'cat_obj_status', 'obj_category_filled', 'cat_obj_overview', 'obj_state_filled',
    'is_obj_funding_total_usd_private'   # funding_round_usd 비공개 플래그 
]

# %% [markdown]
# # founder_master 만들기

# %% [markdown]
# ## rel(창업자 관계만 필터링) - peo : 사람 정보 조인

# %%
# rel(창업자 관계만 필터링) - peo : 사람 정보 조인
founder_rel = rel[rel['cat_rel_title'] == 'Founder'][rel_use_cols].copy()

founder_with_people = founder_rel.merge(
    peo[peo_use_cols],
    how = 'left',
    left_on = 'rel_p_id',
    right_on = 'people_p_id'
)
founder_with_people
# Out:
#        relationship_id  rel_p_id rel_cf_id  is_past  sequence cat_rel_title  \
# 0                    1       p:2       c:1        0         8       Founder
# 1                    9      p:10       c:5        0         1       Founder
# 2                   10      p:11       c:5        1         1       Founder
# 3                   14      p:16    c:7299        1         2       Founder
# 4                   15      p:17    c:7299        1         2       Founder
# ...                ...       ...       ...      ...       ...           ...
# 62110           480741   p:29245  c:286154        1         1       Founder
# 62111           480794  p:254302  c:286157        0         3       Founder
# 62112           480796  p:254302  c:286160        0         4       Founder
# 62113           480797  p:268562  c:286160        0         1       Founder
# 62114           480895  p:268590  c:286215        0         1       Founder
#
#       people_p_id cat_people_birthplace
# 0             p:2                   NaN
# 1            p:10                   NaN
# 2            p:11         United States
# 3            p:16                   NaN
# 4            p:17                   NaN
# ...           ...                   ...
# 62110     p:29245                   NaN
# 62111    p:254302                   NaN
# 62112    p:254302                   NaN
# 62113    p:268562                   NaN
# 62114    p:268590                   NaN
#
# [62115 rows x 8 columns]

# %% [markdown]
# ## degree 최종학력 관련 처리 (degrees_p_id 당 한개의 행으로 집계 -> deg_final_one)

# %% [markdown]
# - 최종학력을 2개 이상을 보유한 사람 존재
#
# - graduated_at 값이 있다면 max로 최근 졸업일 데이터를 가져옴
#
# - 최종학력이 1개인 행들은 그대로 유지
#
# - 나머지 컬럼(학교, 전공 등) 대푯값 붙이기

# %%
# 1️⃣ degrees_p_id별 최종 학위 레벨 계산
max_level = (
    deg
    .groupby('degrees_p_id')['degree_level']
    .transform('max')    # 그룹별 집계와 같이 쓰임. 모든 행에 맞게 확장하여 결과 반환
)

# 2️⃣ 최종 학위에 해당하는 행만 필터
final_degree_rows = deg[deg['degree_level'] == max_level]
final_degree_rows

# degrees_p_id별 행 개수
cnt_per_id = final_degree_rows['degrees_p_id'].value_counts()

# 2행 이상인 degrees_p_id만 추출
multi_ids = cnt_per_id[cnt_per_id >= 2].index

# 해당 degrees_p_id에 속한 모든 행 # 복수 학위를 가진 사람들에 해당하는 모든 행
deg_multi = final_degree_rows[final_degree_rows['degrees_p_id'].isin(multi_ids)]

deg_multi
# Out:
#        degrees_p_id                  degree_type  \
# 12           p:2351                          LLB
# 13           p:2351                           BA
# 27           p:6559                           BA
# 34           p:6614                           BS
# 35           p:6614                           BS
# ...             ...                          ...
# 109257     p:207574                          MBA
# 109278     p:268488  Bachelor of Fine Arts (BFA)
# 109279     p:268488        Bachelor of Arts (BA)
# 109287     p:268428             bachelor of arts
# 109289     p:268428                         B.A.
#
#                                                 subject  \
# 12                                                  Law
# 13                                            Economics
# 27      Communications, Publishing, Social Anthropology
# 34                                           Psychology
# 35                                     criminal jusitce
# ...                                                 ...
# 109257                                              NaN
# 109278                                  Theatre/Theater
# 109279                                  Theatre/Theater
# 109287                                              NaN
# 109289                                              NaN
#
#                                         institution graduated_at  \
# 12              University of Toronto School of Law   1993-01-01
# 13                             Princeton University   1990-01-01
# 27      Simon Fraser University, Ryerson University          NaN
# 34                              University of Texas   1998-01-01
# 35                              University of Texas   1998-01-01
# ...                                             ...          ...
# 109257                         IESE Business School          NaN
# 109278                                SUNY Purchase   2005-01-01
# 109279                Southern Methodist University   2004-01-01
# 109287                         Cambridge University          NaN
# 109289                         Cambridge University          NaN
#
#        cat_degrees_degree_type  degree_level  is_degree_missing  \
# 12           Bachelor’s degree          2.00                  0
# 13           Bachelor’s degree          2.00                  0
# 27           Bachelor’s degree          2.00                  0
# 34           Bachelor’s degree          2.00                  0
# 35           Bachelor’s degree          2.00                  0
# ...                        ...           ...                ...
# 109257         Master’s degree          3.00                  0
# 109278       Bachelor’s degree          2.00                  0
# 109279       Bachelor’s degree          2.00                  0
# 109287       Bachelor’s degree          2.00                  0
# 109289       Bachelor’s degree          2.00                  0
#
#                 cat_degrees_subject         institution_normalized
# 12                              Law             toronto university
# 13      Computer Science / Software           princeton university
# 27       Marketing / Communications        simon fraser university
# 34           Psychology / Sociology               texas university
# 35      Computer Science / Software               texas university
# ...                             ...                            ...
# 109257                          NaN           iese business school
# 109278            Arts / Humanities                            NaN
# 109279            Arts / Humanities  southern methodist university
# 109287                          NaN           cambridge university
# 109289                          NaN           cambridge university
#
# [10062 rows x 10 columns]

# %%
# degrees_p_id별 최종 학위 레벨 계산
max_level = (
    deg
    .groupby('degrees_p_id')['degree_level']
    .transform('max')    # 그룹별 집계와 같이 쓰임. 모든 행에 맞게 확장하여 결과 반환
)

# 최종 학위에 해당하는 행만 필터
final_degree_rows = deg[deg['degree_level'] == max_level]
final_degree_rows

# degrees_p_id별 행 개수
cnt_per_id = final_degree_rows['degrees_p_id'].value_counts()

# 2행 이상인 degrees_p_id만 추출
multi_ids = cnt_per_id[cnt_per_id >= 2].index

# 해당 degrees_p_id에 속한 모든 행 # 복수 학위를 가진 사람들에 해당하는 모든 행
deg_multi = final_degree_rows[final_degree_rows['degrees_p_id'].isin(multi_ids)]

# 날짜컬럼 형식변환
deg_multi["graduated_at"] = pd.to_datetime(deg_multi["graduated_at"], errors="coerce")

# 최근 졸업일자 열 생성
deg_multi["max_graduated_at"] = (
    deg_multi.groupby("degrees_p_id")["graduated_at"]
    .transform("max")
)

# 확인
display(deg_multi[["degrees_p_id", "degree_level", "graduated_at", "max_graduated_at"]])

# 최종학위가 2개 이상인 행들 중 graduated_at 결측 확인
num_missing_graduated_at = deg_multi['graduated_at'].isna().sum()

# 최종학력 2개 이상인 행들 중 졸업일자 결측 비율
print((f"전체 비율: {round((num_missing_graduated_at/deg_multi.shape[0])*100, 2)}%"))
print((f"전체 비율: {round((num_missing_graduated_at/deg.shape[0])*100, 2)}%"))
# Out:
#        degrees_p_id  degree_level graduated_at max_graduated_at
# 12           p:2351          2.00   1993-01-01       1993-01-01
# 13           p:2351          2.00   1990-01-01       1993-01-01
# 27           p:6559          2.00          NaT       2003-01-01
# 34           p:6614          2.00   1998-01-01       1998-01-01
# 35           p:6614          2.00   1998-01-01       1998-01-01
# ...             ...           ...          ...              ...
# 109257     p:207574          3.00          NaT              NaT
# 109278     p:268488          2.00   2005-01-01       2005-01-01
# 109279     p:268488          2.00   2004-01-01       2005-01-01
# 109287     p:268428          2.00          NaT              NaT
# 109289     p:268428          2.00          NaT              NaT
#
# [10062 rows x 4 columns]
# 전체 비율: 44.45%
# 전체 비율: 4.09%

# %%
deg_multi["graduated_at"] = pd.to_datetime(deg_multi["graduated_at"], errors="coerce")

# 날짜가 있는 그룹: idxmax
tmp = deg_multi.dropna(subset=["graduated_at"])
idx1 = tmp.groupby("degrees_p_id")["graduated_at"].idxmax()

# 날짜가 전부 NaN인 그룹: 첫 행을 대표로 선택 → 항상 1행을 보장하고, 실행할 때마다 동일한 결과를 줌
all_na = deg_multi.groupby("degrees_p_id")["graduated_at"].transform(lambda s: s.isna().all())
idx2 = deg_multi.loc[all_na].groupby("degrees_p_id").head(1).index

# ✅ idx1을 Index로 변환해서 합치기
idx = pd.Index(idx1).union(idx2)

deg_multi_one_row = deg_multi.loc[idx].copy()
display(deg_multi_one_row)

print(deg["degrees_p_id"].is_unique)
print(deg_multi_one_row["degrees_p_id"].is_unique)

deg_tmp = deg.copy()

# 1) 치환 대상 p_id 목록
ids = deg_multi_one_row["degrees_p_id"].unique()

# 2) deg에서 해당 p_id 행은 전부 제거(= drop)
deg_keep = deg_tmp.loc[~deg_tmp["degrees_p_id"].isin(ids)].copy()

# 3) 대표행만 다시 붙이기(= replace)
deg_final = pd.concat([deg_keep, deg_multi_one_row], ignore_index=True, sort=False)

# degrees_p_id별 1행인지 점검 (deg_final은 전체적으로는 1행이 아닐 수 있음: p_id가 원래 여러 학력 가진 경우 유지되니까)
# 하지만 ids에 해당하는 p_id는 반드시 1행만 남아야 함
check = deg_final["degrees_p_id"].isin(ids)
assert (deg_final.loc[check, "degrees_p_id"].value_counts() == 1).all()

display(deg_final)

# deg_final에서 중복 degrees_p_id 대표행 선택 기준
# 1. degree_re_level.max()
# 2. graduated_at이 있으면 최신일(max)값이 우선
# 3. 그래도 동률이면 결측이 적은(정보량이 많은 행) 우선

print(deg_final.shape[0])
deg_final.drop_duplicates(keep="first", inplace=True)
print(deg_final.shape[0])

# (1) 중복 현황
dup_size = deg_final.groupby("degrees_p_id").size().sort_values(ascending=False)
print("전체 p_id 수:", deg_final["degrees_p_id"].nunique())
print("전체 행 수:", len(deg_final))
print("중복 p_id 수(2행 이상):", (dup_size >= 2).sum())

# (2) 중복 분포 (2행,3행... 몇 명인지)
display(dup_size.value_counts().sort_index())

# (3) 중복이 있는 p_id 예시 몇 개 보기
dup_ids = dup_size[dup_size >= 2].head(10).index
display(deg_final.loc[deg_final["degrees_p_id"].isin(dup_ids)].sort_values(["degrees_p_id"]))

# 0) 타입 정리
deg_final["degree_level_num"] = pd.to_numeric(deg_final["degree_level"], errors="coerce")
deg_final["graduated_at_dt"] = pd.to_datetime(deg_final["graduated_at"], errors="coerce")

# 1) 규칙 2를 위해: graduated_at 존재 여부 (있으면 1, 없으면 0)
deg_final["has_grad"] = deg_final["graduated_at_dt"].notna().astype(int)

# 2) 규칙 3을 위해: 정보량(결측이 적을수록 큼)
deg_final["non_null_cnt"] = deg_final.notna().sum(axis=1)

# 3) 우선순위대로 정렬
# - degree_re_level_num: 큰 값 우선
# - has_grad: 1(있음) 우선
# - graduated_at_dt: 최신(큰 값) 우선
# - non_null_cnt: 큰 값 우선
# (정렬 안정성을 위해 mergesort 권장)
deg_final_sorted = deg_final.sort_values(
    by=["degrees_p_id", "degree_level_num", "has_grad", "graduated_at_dt", "non_null_cnt"],
    ascending=[True, False, False, False, False],
    kind="mergesort"
)

# 4) p_id당 대표 1행 선택
deg_final_one = deg_final_sorted.drop_duplicates(subset=["degrees_p_id"], keep="first").copy()

# 5) 검증: degrees_p_id가 유니크여야 함
assert deg_final_one["degrees_p_id"].is_unique

# 6) 보조컬럼 정리
deg_final_one = deg_final_one.drop(
    columns=["degree_level_num", "graduated_at_dt", "has_grad", "non_null_cnt"],
    errors="ignore"
)

display(deg_final_one)

deg_final_one["degrees_p_id"].is_unique
# Out:
#        degrees_p_id                  degree_type  \
# 12           p:2351                          LLB
# 34           p:6614                           BS
# 53           p:2371                           BE
# 89           p:7080                           MS
# 133          p:2755                          MBA
# ...             ...                          ...
# 109238     p:268462                          M.S
# 109241     p:268466                      Diploma
# 109256     p:207574                          MSc
# 109278     p:268488  Bachelor of Fine Arts (BFA)
# 109287     p:268428             bachelor of arts
#
#                                             subject  \
# 12                                              Law
# 34                                       Psychology
# 53      Electrical Engineering and Computer Science
# 89                                              MBA
# 133                                             NaN
# ...                                             ...
# 109238                            Materials Science
# 109241                      Business Administration
# 109256                          Information Science
# 109278                              Theatre/Theater
# 109287                                          NaN
#
#                                 institution graduated_at  \
# 12      University of Toronto School of Law   1993-01-01
# 34                      University of Texas   1998-01-01
# 53       University of California, Berkeley          NaT
# 89                       Harvard University   1986-01-01
# 133                  London Business School   2005-01-01
# ...                                     ...          ...
# 109238              Northwestern University          NaT
# 109241                                ICADE          NaT
# 109256                 IESE Business School          NaT
# 109278                        SUNY Purchase   2005-01-01
# 109287                 Cambridge University          NaT
#
#        cat_degrees_degree_type  degree_level  is_degree_missing  \
# 12           Bachelor’s degree          2.00                  0
# 34           Bachelor’s degree          2.00                  0
# 53           Bachelor’s degree          2.00                  0
# 89             Master’s degree          3.00                  0
# 133            Master’s degree          3.00                  0
# ...                        ...           ...                ...
# 109238         Master’s degree          3.00                  0
# 109241        Associate degree          1.00                  0
# 109256         Master’s degree          3.00                  0
# 109278       Bachelor’s degree          2.00                  0
# 109287       Bachelor’s degree          2.00                  0
#
#                         cat_degrees_subject           institution_normalized  \
# 12                                      Law               toronto university
# 34                   Psychology / Sociology                 texas university
# 53              Computer Science / Software  california, berkeley university
# 89                                      NaN               harvard university
# 133                                     NaN           london business school
# ...                                     ...                              ...
# 109238  Mechanical / Industrial Engineering          northwestern university
# 109241              Business Administration                              NaN
# 109256          Computer Science / Software             iese business school
# 109278                    Arts / Humanities                              NaN
# 109287                                  NaN             cambridge university
#
#        max_graduated_at
# 12           1993-01-01
# 34           1998-01-01
# 53                  NaT
# 89           1986-01-01
# 133          2005-01-01
# ...                 ...
# 109238              NaT
# 109241              NaT
# 109256              NaT
# 109278       2005-01-01
# 109287              NaT
#
# [4888 rows x 11 columns]
# False
# True
#        degrees_p_id                  degree_type  \
# 0            p:6117                          MBA
# 1            p:6136                           BA
# 2            p:6136                           MS
# 3            p:6005                           MS
# 4            p:5832                          BCS
# ...             ...                          ...
# 101528     p:268462                          M.S
# 101529     p:268466                      Diploma
# 101530     p:207574                          MSc
# 101531     p:268488  Bachelor of Fine Arts (BFA)
# 101532     p:268428             bachelor of arts
#
#                              subject                       institution  \
# 0                                NaN                               NaN
# 1                    English, French  Washington University, St. Louis
# 2                 Mass Communication                 Boston University
# 3                Internet Technology           University of Greenwich
# 4       Computer Science, Psychology                   Rice University
# ...                              ...                               ...
# 101528             Materials Science           Northwestern University
# 101529       Business Administration                             ICADE
# 101530           Information Science              IESE Business School
# 101531               Theatre/Theater                     SUNY Purchase
# 101532                           NaN              Cambridge University
#
#                graduated_at cat_degrees_degree_type  degree_level  \
# 0                       NaN         Master’s degree          3.00
# 1                1990-01-01       Bachelor’s degree          2.00
# 2                1992-01-01         Master’s degree          3.00
# 3                2006-01-01         Master’s degree          3.00
# 4                       NaN       Bachelor’s degree          2.00
# ...                     ...                     ...           ...
# 101528                  NaT         Master’s degree          3.00
# 101529                  NaT        Associate degree          1.00
# 101530                  NaT         Master’s degree          3.00
# 101531  2005-01-01 00:00:00       Bachelor’s degree          2.00
# 101532                  NaT       Bachelor’s degree          2.00
#
#         is_degree_missing                  cat_degrees_subject  \
# 0                       0                                  NaN
# 1                       0                    Arts / Humanities
# 2                       0           Marketing / Communications
# 3                       0          Computer Science / Software
# 4                       0          Computer Science / Software
# ...                   ...                                  ...
# 101528                  0  Mechanical / Industrial Engineering
# 101529                  0              Business Administration
# 101530                  0          Computer Science / Software
# 101531                  0                    Arts / Humanities
# 101532                  0                                  NaN
#
#          institution_normalized max_graduated_at
# 0                           NaN              NaT
# 1         washington university              NaT
# 2             boston university              NaT
# 3          greenwich university              NaT
# 4               rice university              NaT
# ...                         ...              ...
# 101528  northwestern university              NaT
# 101529                      NaN              NaT
# 101530     iese business school              NaT
# 101531                      NaN       2005-01-01
# 101532     cambridge university              NaT
#
# [101533 rows x 11 columns]
# 101533
# 101533
# 전체 p_id 수: 68451
# 전체 행 수: 101533
# 중복 p_id 수(2행 이상): 27401
# 1     41050
# 2     22576
# 3      4121
# 4       598
# 5        76
# 6        20
# 7         7
# 8         1
# 9         1
# 10        1
# Name: count, dtype: int64
#       degrees_p_id                       degree_type  \
# 26087     p:183805  Microsoft Project 2007 Full Edit
# 26091     p:183805                           5 years
# 26090     p:183805                Thesis development
# 26089     p:183805                   Training course
# 26088     p:183805     EEF Foundations Summer School
# 26086     p:183805  Certified Tester Foundation Leve
# 26085     p:183805  Certified Tester Advanced Level
# 26092     p:183805                           Diploma
# 26084     p:183805       ITIL Foundation Certificate
# 26093     p:183805                               NaN
# 54197     p:216686                            Degree
# 54198     p:216686                            Degree
# 55344     p:216686               Executive Education
# 54195     p:216686                               MBA
# 54192     p:216686                       Certificate
# 54191     p:216686  Institute of Corporate Directors
# 54196     p:216686                              BASC
# 58364     p:222431                              BCOM
# 58362     p:222431                               LLB
# 58363     p:222431                             M.COM
# 58358     p:222431                              EPAF
# 58359     p:222431                               MBA
# 58360     p:222431                              FCMA
# 58361     p:222431                               FCS
# 65550     p:229227                                JD
# 65551     p:229227                                MA
# 65549     p:229227                               MBA
# 65553     p:229227                            Degree
# 65552     p:229227                                BA
# 65554     p:229227                            Degree
# 65555     p:229227                            Degree
# 70699     p:234052                               DBA
# 70705     p:234052                            Degree
# 70701     p:234052                               MBA
# 70700     p:234052                  Graduate Diploma
# 70703     p:234052                                BA
# 70704     p:234052                           Diploma
# 70702     p:234052             Post-Graduate Diploma
# 44507      p:25763             Executive Certificate
# 45656      p:25763             Executive Certificate
# 44508      p:25763                               MAS
# 44509      p:25763                               MES
# 44505      p:25763             Post-Grad Certificate
# 44506      p:25763                                MS
# 44510      p:25763                                BA
# 52978      p:65231                               MBI
# 52975      p:65231                       Negociación
# 52976      p:65231  Industrial Organization Engineer
# 52974      p:65231                      Ph. D course
# 52973      p:65231                        Innovation
# 52972      p:65231  Entrepreneurship Development Pro
# 52971      p:65231                 DIGITAL MARKETING
# 52977      p:65231  Industrial Technical Engineer (I
# 51926      p:70132                         Seminario
# 51924      p:70132                               NaN
# 51923      p:70132                     Seminario SEO
# 51922      p:70132                            Basico
# 51921      p:70132                           Nivel 3
# 51920      p:70132                               NaN
# 51925      p:70132                     Seminario BTL
# 72827      p:70892                               NaN
# 45308      p:70892                               NaN
# 45307      p:70892                               NaN
# 45306      p:70892                               NaN
# 45305      p:70892                               NaN
# 45304      p:70892                               NaN
# 45309      p:70892                               NaN
# 21040      p:93386                       Certificate
# 21039      p:93386                       Certificate
# 12527      p:93386                       Certificate
# 12526      p:93386                                BS
# 12525      p:93386                       Certificate
# 12524      p:93386                                MS
# 12523      p:93386                                JD
# 12522      p:93386                       Certificate
# 12521      p:93386                       Certificate
#
#                                                           subject  \
# 26087                                                         NaN
# 26091                                            Computer science
# 26090                           Symbolic solutions for Petri Nets
# 26089                                          PVS Theorem Prover
# 26088                   Concurrency (Concurrent Software Systems)
# 26086                                            Software Testing
# 26085                                            Software Testing
# 26092                                         Aviation Technology
# 26084                                       IT Service Management
# 26093                                                         NaN
# 54197                                                      Degree
# 54198                                                      Degree
# 55344                                                         NaN
# 54195                                           Finance, Strategy
# 54192                               Entrepreneurship Development,
# 54191                      Directors Education Program, Completed
# 54196                                      Electrical Engineering
# 58364                                                    COMMERCE
# 58362                                                         Law
# 58363                                                    Commerce
# 58358                                             Applied Finance
# 58359                                                         MBA
# 58360                                             Cost Accountant
# 58361                                           Company Secretary
# 65550                                                         Law
# 65551                                            Computer Science
# 65549                                         Finance & Marketing
# 65553  Biochemistry, Chemical Engineering, Mechanical Engineering
# 65552                                                   Chemistry
# 65554                                                      Degree
# 65555                                                      Degree
# 70699                                       Business & Management
# 70705                                                      Degree
# 70701                           International Business Management
# 70700                                         Management Research
# 70703                                     Business Administration
# 70704                                      Electrical Engineering
# 70702                                       Facilities Management
# 44507                           Marketing Innovative Technologies
# 45656                             Negotiation - Changing the Game
# 44508                                       Telematics Management
# 44509                                  Master of European Studies
# 44505                      Entrepreneurship Post-Graduate Studies
# 44506                                Telecommunication Management
# 44510                                       International Studies
# 52978             Business Administration and Management, General
# 52975                                                         NaN
# 52976                                                         NaN
# 52974                                         Language processing
# 52973                                                         NaN
# 52972                                                         NaN
# 52971                                                         NaN
# 52977      Electrical, Electronics and Communications Engineering
# 51926            Comunicaciones Internas, Comunicaciones Internas
# 51924                                Curso Intesivo Photoshop CS2
# 51923                                                         SEO
# 51922                                                   Portugues
# 51921                                                       CHINO
# 51920              Comunicación 2.0, Comunicación. Social Media.-
# 51925                                     Comunicaciones Internas
# 72827                               Certified Agile Product Owner
# 45308                                               Communication
# 45307                        PMP, Project Management Proffesional
# 45306                                 CSM, Certified Scrum Master
# 45305                           CSP, Certifed Scrum Proffessional
# 45304                               Certified Scrum Product Owner
# 45309                                                   Sociology
# 21040                                 High Performance Leadership
# 21039                                      Managing for Execution
# 12527                             Insurance Replacement Appraisal
# 12526                         Business Administration: Accounting
# 12525                  Professional Practice in Internal Auditing
# 12524                                                         CIS
# 12523                                         Public Interest Law
# 12522                   Sustainable Energy Conversion and Storage
# 12521                                           Change Leadership
#
#                                                             institution  \
# 26087                             European School of Project Management
# 26091                                  Università degli Studi di Torino
# 26090                               William & Mary College, Willamsburg
# 26089  NASA Langley Research Center, National Institute for Aerospace,
# 26088                                     EEF Foundations Summer School
# 26086                International Software Testing Qualification Board
# 26085                International Software Testing Qualification Board
# 26092                                             I.T.I.S. Carlo Grassi
# 26084                            Information Systems Examinations Board
# 26093                                           Fedeli Compagne di Gesù
# 54197                                            Mbale Secondary School
# 54198                                  Institute of Corporate Directors
# 55344                                                   Duke University
# 54195                                              University of Ottawa
# 54192  Massachusetts Institute of Technology (MIT), Sloan School of Man
# 54191                University of Toronto, Rotman School of Management
# 54196                                            University of Waterloo
# 58364                                                 Panjab University
# 58362                                                 Panjab University
# 58363                                       Himachal Pradesh University
# 58358                          Indian Institute of Management, Calcutta
# 58359                            Indira Gandhi National Open University
# 58360          Institute of Cost and Works Accountants of India - ICWAI
# 58361                         Institute of Company Secretaries of India
# 65550                                 Wayne State University Law School
# 65551                                            Wayne State University
# 65549          The University of Texas at Dallas - School of Management
# 65553                                     University of Texas at Austin
# 65552                                            Wayne State University
# 65554                                                      JJ Pearce HS
# 65555                                        St. Mark's School of Texas
# 70699                                     University of South Australia
# 70705                                          Nan Hua Secondary School
# 70701                                     University of South Australia
# 70700                                     University of South Australia
# 70703  University of Bolton (formerly known as Bolton Institute of High
# 70704                                              Ngee Ann Polytechnic
# 70702                                       Sheffield Hallam University
# 44507                                                               HBS
# 45656                                                               HBS
# 44508                                           Danube University Krems
# 44509                                           Danube University Krems
# 44505                       Hochschule Luzern - Danube University Krems
# 44506                                           Danube University Krems
# 44510                                                 Maryville College
# 52978                                            Deusto Business School
# 52975                                          Tecnológico de Monterrey
# 52976                                             Universidad de Deusto
# 52974          Universidad del País Vasco/Euskal Herriko Unibertsitatea
# 52973  Massachusetts Institute of Technology (MIT), Sloan School of Man
# 52972  Massachusetts Institute of Technology (MIT), Sloan School of Man
# 52971                                           Harvard Business School
# 52977                                             Universidad de Deusto
# 51926                                       Universidad de Buenos Aires
# 51924                                                          Da Vinci
# 51923                                            Universidad de Palermo
# 51922                         CUI (Centro Universitario de Idiomas UBA)
# 51921                             CUI (Centro Universitario de idiomas)
# 51920                                 Universidad de Buenos Aires / UBA
# 51925                                       Universidad de Buenos Aires
# 72827                                                    Rally Software
# 45308                           State University of New York at Buffalo
# 45307                                                     PMI Institute
# 45306                                            Big Visiable Solutions
# 45305                                                    Scrum Alliance
# 45304                                                    Scrum Alliance
# 45309                                      Saint Bonaventure University
# 21040                                                Cornell University
# 21039                                                Cornell University
# 12527                                  Gemological Institute of America
# 12526                             San Francisco State University (SFSU)
# 12525                             San Francisco State University (SFSU)
# 12524                                             University of Phoenix
# 12523                           New College of California School of Law
# 12522                                               Stanford University
# 12521                                                Cornell University
#
#       graduated_at cat_degrees_degree_type  degree_level  is_degree_missing  \
# 26087   2010-01-01                  Others          0.00                  0
# 26091   2003-01-01         Master’s degree          3.00                  0
# 26090   2003-01-01                  Others          0.00                  0
# 26089   2003-01-01                  Others          0.00                  0
# 26088   2003-01-01                  Others          0.00                  0
# 26086   2011-01-01                  Others          0.00                  0
# 26085   2012-01-01                  Others          0.00                  0
# 26092   1994-01-01        Associate degree          1.00                  0
# 26084   2012-01-01                  Others          0.00                  0
# 26093          NaN                     NaN           NaN                  1
# 54197   1972-01-01                  Others          0.00                  0
# 54198          NaN                  Others          0.00                  0
# 55344   1987-01-01                  Others          0.00                  0
# 54195   1989-01-01         Master’s degree          3.00                  0
# 54192   2010-01-01        Associate degree          1.00                  0
# 54191   2012-01-01                  Others          0.00                  0
# 54196   1979-01-01        Associate degree          1.00                  0
# 58364   1980-01-01       Bachelor’s degree          2.00                  0
# 58362   1986-01-01       Bachelor’s degree          2.00                  0
# 58363   1982-01-01                  Others          0.00                  0
# 58358   2010-01-01                  Others          0.00                  0
# 58359   1993-01-01         Master’s degree          3.00                  0
# 58360   1991-01-01                  Others          0.00                  0
# 58361   1988-01-01                  Others          0.00                  0
# 65550   2000-01-01               Doctorate          4.00                  0
# 65551   1999-01-01         Master’s degree          3.00                  0
# 65549   2010-01-01         Master’s degree          3.00                  0
# 65553   1993-01-01       Bachelor’s degree          2.00                  0
# 65552   1994-01-01       Bachelor’s degree          2.00                  0
# 65554   1989-01-01                  Others          0.00                  0
# 65555   1987-01-01                  Others          0.00                  0
# 70699   2012-01-01               Doctorate          4.00                  0
# 70705   1989-01-01                  Others          0.00                  0
# 70701   2003-01-01         Master’s degree          3.00                  0
# 70700   2007-01-01         Master’s degree          3.00                  0
# 70703   1996-01-01       Bachelor’s degree          2.00                  0
# 70704   1993-01-01        Associate degree          1.00                  0
# 70702   2001-01-01         Master’s degree          3.00                  0
# 44507   2002-01-01                  Others          0.00                  0
# 45656   2007-01-01                  Others          0.00                  0
# 44508   1998-01-01        Associate degree          1.00                  0
# 44509   1997-01-01                  Others          0.00                  0
# 44505   2008-01-01       Bachelor’s degree          2.00                  0
# 44506   2004-01-01         Master’s degree          3.00                  0
# 44510   1996-01-01       Bachelor’s degree          2.00                  0
# 52978          NaN                  Others          0.00                  0
# 52975   2005-01-01                  Others          0.00                  0
# 52976   2005-01-01                  Others          0.00                  0
# 52974   2007-01-01               Doctorate          4.00                  0
# 52973   2009-01-01                  Others          0.00                  0
# 52972   2009-01-01                  Others          0.00                  0
# 52971   2009-01-01                  Others          0.00                  0
# 52977   2003-01-01                  Others          0.00                  0
# 51926   2006-01-01                  Others          0.00                  0
# 51924   2007-01-01                     NaN           NaN                  1
# 51923   2008-01-01                  Others          0.00                  0
# 51922   2011-01-01        Associate degree          1.00                  0
# 51921   2013-01-01                  Others          0.00                  0
# 51920   2013-01-01                     NaN           NaN                  1
# 51925   2007-01-01                  Others          0.00                  0
# 72827   2012-01-01                     NaN           NaN                  1
# 45308   1999-01-01                     NaN           NaN                  1
# 45307   2008-01-01                     NaN           NaN                  1
# 45306   2009-01-01                     NaN           NaN                  1
# 45305   2010-01-01                     NaN           NaN                  1
# 45304   2013-01-01                     NaN           NaN                  1
# 45309   1997-01-01                     NaN           NaN                  1
# 21040   2011-01-01        Associate degree          1.00                  0
# 21039   2011-01-01        Associate degree          1.00                  0
# 12527   1996-01-01        Associate degree          1.00                  0
# 12526   1995-01-01       Bachelor’s degree          2.00                  0
# 12525   1995-01-01        Associate degree          1.00                  0
# 12524   1998-01-01         Master’s degree          3.00                  0
# 12523   2001-01-01               Doctorate          4.00                  0
# 12522   2011-01-01        Associate degree          1.00                  0
# 12521   2011-01-01        Associate degree          1.00                  0
#
#                                cat_degrees_subject  \
# 26087                                          NaN
# 26091                  Computer Science / Software
# 26090                             Others / Unknown
# 26089                   Marketing / Communications
# 26088                  Computer Science / Software
# 26086                  Computer Science / Software
# 26085                  Computer Science / Software
# 26092                  Computer Science / Software
# 26084                  Computer Science / Software
# 26093                                          NaN
# 54197                                          NaN
# 54198                                          NaN
# 55344                                          NaN
# 54195                         Finance / Accounting
# 54192                   Marketing / Communications
# 54191                   Marketing / Communications
# 54196                  Computer Science / Software
# 58364                   Marketing / Communications
# 58362                                          Law
# 58363                   Marketing / Communications
# 58358                         Finance / Accounting
# 58359                                          NaN
# 58360                             Others / Unknown
# 58361                             Others / Unknown
# 65550                                          Law
# 65551                  Computer Science / Software
# 65549                   Marketing / Communications
# 65553                  Computer Science / Software
# 65552                  Computer Science / Software
# 65554                                          NaN
# 65555                                          NaN
# 70699                         Finance / Accounting
# 70705                                          NaN
# 70701                         Finance / Accounting
# 70700                         Finance / Accounting
# 70703                      Business Administration
# 70704                  Computer Science / Software
# 70702                  Computer Science / Software
# 44507                   Marketing / Communications
# 45656                             Others / Unknown
# 44508                  Computer Science / Software
# 44509                            Arts / Humanities
# 44505                   Marketing / Communications
# 44506                   Marketing / Communications
# 44510  Political Science / International Relations
# 52978                         Finance / Accounting
# 52975                                          NaN
# 52976                                          NaN
# 52974                   Marketing / Communications
# 52973                                          NaN
# 52972                                          NaN
# 52971                                          NaN
# 52977                   Marketing / Communications
# 51926                             Others / Unknown
# 51924                  Computer Science / Software
# 51923                             Others / Unknown
# 51922                             Others / Unknown
# 51921                             Others / Unknown
# 51920                   Marketing / Communications
# 51925                             Others / Unknown
# 72827                   Marketing / Communications
# 45308                   Marketing / Communications
# 45307                   Marketing / Communications
# 45306                  Computer Science / Software
# 45305                   Marketing / Communications
# 45304                   Marketing / Communications
# 45309                       Psychology / Sociology
# 21040                      Business Administration
# 21039                             Others / Unknown
# 12527                   Marketing / Communications
# 12526                         Finance / Accounting
# 12525                   Marketing / Communications
# 12524                  Computer Science / Software
# 12523                                          Law
# 12522                             Others / Unknown
# 12521                      Business Administration
#
#                                                  institution_normalized  \
# 26087                             european school of project management
# 26091                                  università degli studi di torino
# 26090                                            william & mary college
# 26089    nasa langley research center, national institute for aerospace
# 26088                                     eef foundations summer school
# 26086                international software testing qualification board
# 26085                international software testing qualification board
# 26092                                             i.t.i.s. carlo grassi
# 26084                            information systems examinations board
# 26093                                           fedeli compagne di gesù
# 54197                                            mbale secondary school
# 54198                                  institute of corporate directors
# 55344                                                   duke university
# 54195                                                 ottawa university
# 54192  massachusetts institute of technology (mit), sloan school of man
# 54191                                        toronto, rotman university
# 54196                                               waterloo university
# 58364                                                 panjab university
# 58362                                                 panjab university
# 58363                                       himachal pradesh university
# 58358                          indian institute of management, calcutta
# 58359                            indira gandhi national open university
# 58360          institute of cost and works accountants of india - icwai
# 58361                         institute of company secretaries of india
# 65550                                            wayne state university
# 65551                                            wayne state university
# 65549                                      texas at dallas - university
# 65553                                        texas at austin university
# 65552                                            wayne state university
# 65554                                                      jj pearce hs
# 65555                                        st. mark's school of texas
# 70699                                        south australia university
# 70705                                          nan hua secondary school
# 70701                                        south australia university
# 70700                                        south australia university
# 70703                                                 bolton university
# 70704                                              ngee ann polytechnic
# 70702                                       sheffield hallam university
# 44507                                                               NaN
# 45656                                                               NaN
# 44508                                                 danube university
# 44509                                                 danube university
# 44505                             hochschule luzern - danube university
# 44506                                                 danube university
# 44510                                                 maryville college
# 52978                                            deusto business school
# 52975                                          tecnológico de monterrey
# 52976                                             universidad de deusto
# 52974          universidad del país vasco/euskal herriko unibertsitatea
# 52973  massachusetts institute of technology (mit), sloan school of man
# 52972  massachusetts institute of technology (mit), sloan school of man
# 52971                                                harvard university
# 52977                                             universidad de deusto
# 51926                                       universidad de buenos aires
# 51924                                                               NaN
# 51923                                            universidad de palermo
# 51922                         cui (centro universitario de idiomas uba)
# 51921                             cui (centro universitario de idiomas)
# 51920                                 universidad de buenos aires / uba
# 51925                                       universidad de buenos aires
# 72827                                                               NaN
# 45308                                    new york at buffalo university
# 45307                                                     pmi institute
# 45306                                            big visiable solutions
# 45305                                                               NaN
# 45304                                                               NaN
# 45309                                      saint bonaventure university
# 21040                                                cornell university
# 21039                                                cornell university
# 12527                                  gemological institute of america
# 12526                                    san francisco state university
# 12525                                    san francisco state university
# 12524                                                phoenix university
# 12523                                                       new college
# 12522                                               stanford university
# 12521                                                cornell university
#
#       max_graduated_at
# 26087              NaT
# 26091              NaT
# 26090              NaT
# 26089              NaT
# 26088              NaT
# 26086              NaT
# 26085              NaT
# 26092              NaT
# 26084              NaT
# 26093              NaT
# 54197              NaT
# 54198              NaT
# 55344              NaT
# 54195              NaT
# 54192              NaT
# 54191              NaT
# 54196              NaT
# 58364              NaT
# 58362              NaT
# 58363              NaT
# 58358              NaT
# 58359              NaT
# 58360              NaT
# 58361              NaT
# 65550              NaT
# 65551              NaT
# 65549              NaT
# 65553              NaT
# 65552              NaT
# 65554              NaT
# 65555              NaT
# 70699              NaT
# 70705              NaT
# 70701              NaT
# 70700              NaT
# 70703              NaT
# 70704              NaT
# 70702              NaT
# 44507              NaT
# 45656              NaT
# 44508              NaT
# 44509              NaT
# 44505              NaT
# 44506              NaT
# 44510              NaT
# 52978              NaT
# 52975              NaT
# 52976              NaT
# 52974              NaT
# 52973              NaT
# 52972              NaT
# 52971              NaT
# 52977              NaT
# 51926              NaT
# 51924              NaT
# 51923              NaT
# 51922              NaT
# 51921              NaT
# 51920              NaT
# 51925              NaT
# 72827              NaT
# 45308              NaT
# 45307              NaT
# 45306              NaT
# 45305              NaT
# 45304              NaT
# 45309              NaT
# 21040              NaT
# 21039              NaT
# 12527              NaT
# 12526              NaT
# 12525              NaT
# 12524              NaT
# 12523              NaT
# 12522              NaT
# 12521              NaT
#       degrees_p_id  degree_type                            subject  \
# 2195          p:10          NaN                   Computer Science
# 73646     p:100006          MBA               Strategy & Marketing
# 98252     p:100013          MBA                            Finance
# 12924     p:100018          MBA        Entrepreneurship, Marketing
# 12927     p:100031           BS  Information Science & Engineering
# ...            ...          ...                                ...
# 12921      p:99983          NaN                            Finance
# 12922      p:99988           BS         Maths and Computer Science
# 13025      p:99990  engineering                                NaN
# 90350      p:99994           BE     Electronics and Communications
# 61580      p:99997           BA                     Communications
#
#                                 institution graduated_at  \
# 2195                     Harvard University          NaN
# 73646        MIT Sloan School of Management   2004-01-01
# 98252                    Rutgers University          NaT
# 12924  Columbia University, Business School   2004-01-01
# 12927         Gogte Institute of Technology   2010-01-01
# ...                                     ...          ...
# 12921              University of Washington          NaN
# 12922                    Bristol University   2004-01-01
# 13025                              Technion   1971-01-01
# 90350           University of Madras, India          NaN
# 61580                  University of Ottawa   1993-01-01
#
#       cat_degrees_degree_type  degree_level  is_degree_missing  \
# 2195                      NaN           NaN                  1
# 73646         Master’s degree          3.00                  0
# 98252         Master’s degree          3.00                  0
# 12924         Master’s degree          3.00                  0
# 12927       Bachelor’s degree          2.00                  0
# ...                       ...           ...                ...
# 12921                     NaN           NaN                  1
# 12922       Bachelor’s degree          2.00                  0
# 13025                  Others          0.00                  0
# 90350       Bachelor’s degree          2.00                  0
# 61580       Bachelor’s degree          2.00                  0
#
#                cat_degrees_subject          institution_normalized  \
# 2195   Computer Science / Software              harvard university
# 73646   Marketing / Communications  mit sloan school of management
# 98252         Finance / Accounting              rutgers university
# 12924   Marketing / Communications             columbia university
# 12927  Computer Science / Software   gogte institute of technology
# ...                            ...                             ...
# 12921         Finance / Accounting           washington university
# 12922  Computer Science / Software              bristol university
# 13025                          NaN                        technion
# 90350   Marketing / Communications        madras, india university
# 61580   Marketing / Communications               ottawa university
#
#       max_graduated_at
# 2195               NaT
# 73646              NaT
# 98252              NaT
# 12924              NaT
# 12927              NaT
# ...                ...
# 12921              NaT
# 12922              NaT
# 13025              NaT
# 90350              NaT
# 61580              NaT
#
# [68451 rows x 11 columns]
# True

# %% [markdown]
# ## founder_with_people와 deg_final_one(최종학력 행만 남김) 최종학력 조인

# %%
# 학력 정보 조인 (deg) - 최종학력 행만 남기기 
founder_profile = founder_with_people.merge(
    deg_final_one,
    how = 'left',
    left_on = 'people_p_id',
    right_on = 'degrees_p_id'
)
founder_profile      # ✅ 1 row = 창업자 x 회사 x 출생지 x 학위수준 x 전공 x 학교

# 회사 정보 조인 (company만 필터)
companies = obj[obj['objects_cfpr_id'].str.startswith('c:')][obj_use_cols].copy()

founder_company = founder_profile.merge(
    companies,
    how = 'left',
    left_on = 'rel_cf_id',
    right_on = 'objects_cfpr_id'
)
founder_company
founder_profile
# Out:
#        relationship_id  rel_p_id rel_cf_id  is_past  sequence cat_rel_title  \
# 0                    1       p:2       c:1        0         8       Founder
# 1                    9      p:10       c:5        0         1       Founder
# 2                   10      p:11       c:5        1         1       Founder
# 3                   14      p:16    c:7299        1         2       Founder
# 4                   15      p:17    c:7299        1         2       Founder
# ...                ...       ...       ...      ...       ...           ...
# 62110           480741   p:29245  c:286154        1         1       Founder
# 62111           480794  p:254302  c:286157        0         3       Founder
# 62112           480796  p:254302  c:286160        0         4       Founder
# 62113           480797  p:268562  c:286160        0         1       Founder
# 62114           480895  p:268590  c:286215        0         1       Founder
#
#       people_p_id cat_people_birthplace degrees_p_id degree_type  \
# 0             p:2                   NaN          p:2          BS
# 1            p:10                   NaN         p:10         NaN
# 2            p:11         United States         p:11   No degree
# 3            p:16                   NaN         p:16          BA
# 4            p:17                   NaN         p:17         NaN
# ...           ...                   ...          ...         ...
# 62110     p:29245                   NaN          NaN         NaN
# 62111    p:254302                   NaN          NaN         NaN
# 62112    p:254302                   NaN          NaN         NaN
# 62113    p:268562                   NaN          NaN         NaN
# 62114    p:268590                   NaN          NaN         NaN
#
#                                        subject  \
# 0      Electrical Engineering/Computer Science
# 1                             Computer Science
# 2                                          NaN
# 3                 Computer Information Systems
# 4                       Electrical Engineering
# ...                                        ...
# 62110                                      NaN
# 62111                                      NaN
# 62112                                      NaN
# 62113                                      NaN
# 62114                                      NaN
#
#                               institution         graduated_at  \
# 0      University of California, Berkeley  1994-01-01 00:00:00
# 1                      Harvard University                  NaN
# 2                      Harvard University                  NaN
# 3               Colorado State University                  NaN
# 4           University of Texas at Austin                  NaN
# ...                                   ...                  ...
# 62110                                 NaN                  NaN
# 62111                                 NaN                  NaN
# 62112                                 NaN                  NaN
# 62113                                 NaN                  NaN
# 62114                                 NaN                  NaN
#
#       cat_degrees_degree_type  degree_level  is_degree_missing  \
# 0           Bachelor’s degree          2.00               0.00
# 1                         NaN           NaN               1.00
# 2           Bachelor’s degree          2.00               0.00
# 3           Bachelor’s degree          2.00               0.00
# 4                         NaN           NaN               1.00
# ...                       ...           ...                ...
# 62110                     NaN           NaN                NaN
# 62111                     NaN           NaN                NaN
# 62112                     NaN           NaN                NaN
# 62113                     NaN           NaN                NaN
# 62114                     NaN           NaN                NaN
#
#                cat_degrees_subject           institution_normalized  \
# 0      Computer Science / Software  california, berkeley university
# 1      Computer Science / Software               harvard university
# 2                              NaN               harvard university
# 3      Computer Science / Software        colorado state university
# 4      Computer Science / Software       texas at austin university
# ...                            ...                              ...
# 62110                          NaN                              NaN
# 62111                          NaN                              NaN
# 62112                          NaN                              NaN
# 62113                          NaN                              NaN
# 62114                          NaN                              NaN
#
#       max_graduated_at
# 0           1994-01-01
# 1                  NaT
# 2                  NaT
# 3                  NaT
# 4                  NaT
# ...                ...
# 62110              NaT
# 62111              NaT
# 62112              NaT
# 62113              NaT
# 62114              NaT
#
# [62115 rows x 19 columns]

# %%
founder_profile.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## founder_profile을 집계 : rel_p_id, rel_cf_id 기준

# %%
founder_profile.columns
# Out:
# Index(['relationship_id', 'rel_p_id', 'rel_cf_id', 'is_past', 'sequence',
#        'cat_rel_title', 'people_p_id', 'cat_people_birthplace', 'degrees_p_id',
#        'degree_type', 'subject', 'institution', 'graduated_at',
#        'cat_degrees_degree_type', 'degree_level', 'is_degree_missing',
#        'cat_degrees_subject', 'institution_normalized', 'max_graduated_at'],
#       dtype='object')

# %%
# rel_p_id, rel_cf_id 기준 집계 : agg_founder_profile
agg_founder_profile = founder_profile.groupby(['rel_p_id', 'rel_cf_id']).agg(
    is_past      = ('is_past', 'first'),
    sequence     = ('sequence', 'max'),
    birthplace   = ('cat_people_birthplace', 'first'),
    degree_level = ('degree_level', 'max'),
    subject      = ('cat_degrees_subject', 'first'),
    institution  = ('institution_normalized', 'first'),
    graduated_at = ('graduated_at', 'first')
).reset_index()

# %%
# agg_founder_profile 에서 c:만 필터링 (이유 : 창업자와 창업한 회사만 보고, 투자자는 제외하려고)
c_agg_founder_profile = agg_founder_profile[agg_founder_profile['rel_cf_id'].str.startswith('c:')].copy()
c_agg_founder_profile
# Out:
#        rel_p_id rel_cf_id  is_past  sequence birthplace  degree_level  \
# 0          p:10       c:5        0         1       None           NaN
# 2      p:100009  c:152329        0         1       None           NaN
# 3      p:100009   c:81559        0         2       None           NaN
# 4      p:100017   c:81564        0         1       None           NaN
# 5      p:100025     c:287        0         1       None           NaN
# ...         ...       ...      ...       ...        ...           ...
# 61822   p:99982   c:16993        1         1       None           NaN
# 61823   p:99982   c:81541        0         2       None           NaN
# 61824   p:99988   c:64683        0         1       None          2.00
# 61825   p:99994    c:3643        0         1       None          2.00
# 61826   p:99997   c:83651        0         7     Canada          2.00
#
#                            subject               institution graduated_at
# 0      Computer Science / Software        harvard university         None
# 2                             None                      None         None
# 3                             None                      None         None
# 4                             None                      None         None
# 5                             None                      None         None
# ...                            ...                       ...          ...
# 61822                         None                      None         None
# 61823                         None                      None         None
# 61824  Computer Science / Software        bristol university   2004-01-01
# 61825   Marketing / Communications  madras, india university         None
# 61826   Marketing / Communications         ottawa university   1993-01-01
#
# [59966 rows x 9 columns]

# %% [markdown]
# ## 창업자가 창업한 회사(c:)의 수 = 즉, 창업경험 수

# %%
# 창업자가 창업한 회사 수 : cnt_founding
cnt_founding = c_agg_founder_profile.groupby('rel_p_id').agg(
    n_founding = ('rel_cf_id', 'nunique')
)
cnt_founding
# Out:
#           n_founding
# rel_p_id
# p:10               1
# p:100009           2
# p:100017           1
# p:100025           1
# p:100026           1
# ...              ...
# p:99980            4
# p:99982            2
# p:99988            1
# p:99994            1
# p:99997            1
#
# [50021 rows x 1 columns]

# %% [markdown]
# ## c_agg_founder_profile과 cnt_founding을 merge

# %%
# agg_founder_profile과 cnt_founding을 merge
founder_master = c_agg_founder_profile.merge(
    cnt_founding,
    how = 'left',
    on = 'rel_p_id'
)
founder_master

# 컬럼 순서 변경
fm_cols = ['rel_p_id', 'rel_cf_id', 'n_founding', 'is_past', 'sequence', 
    'birthplace', 'degree_level', 'subject', 'institution', 'graduated_at'
    ]
founder_master = founder_master[fm_cols]
founder_master
# Out:
#        rel_p_id rel_cf_id  n_founding  is_past  sequence birthplace  \
# 0          p:10       c:5           1        0         1       None
# 1      p:100009  c:152329           2        0         1       None
# 2      p:100009   c:81559           2        0         2       None
# 3      p:100017   c:81564           1        0         1       None
# 4      p:100025     c:287           1        0         1       None
# ...         ...       ...         ...      ...       ...        ...
# 59961   p:99982   c:16993           2        1         1       None
# 59962   p:99982   c:81541           2        0         2       None
# 59963   p:99988   c:64683           1        0         1       None
# 59964   p:99994    c:3643           1        0         1       None
# 59965   p:99997   c:83651           1        0         7     Canada
#
#        degree_level                      subject               institution  \
# 0               NaN  Computer Science / Software        harvard university
# 1               NaN                         None                      None
# 2               NaN                         None                      None
# 3               NaN                         None                      None
# 4               NaN                         None                      None
# ...             ...                          ...                       ...
# 59961           NaN                         None                      None
# 59962           NaN                         None                      None
# 59963          2.00  Computer Science / Software        bristol university
# 59964          2.00   Marketing / Communications  madras, india university
# 59965          2.00   Marketing / Communications         ottawa university
#
#       graduated_at
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
# ...            ...
# 59961         None
# 59962         None
# 59963   2004-01-01
# 59964         None
# 59965   1993-01-01
#
# [59966 rows x 10 columns]

# %% [markdown]
# #### 스타트업의 창업자 조건(with 수아님) : 투자기업 창업자(투자만 행한)만 제외한 모든 스타트업의 창업자

# %%
# 0) 투자자 / 투자받은 회사 ID 집합
investor_ids = set(inv['investor_cfp_id'].dropna())
invested_ids = set(inv['invested_c_id'].dropna())

# 1) 투자자 전용 ID (투자만 하고, 투자받지 않은 주체)
pure_investor_ids = investor_ids - invested_ids

# 2) 조건 1: 금융기관(f:) 제외
cond1 = ~founder_master['rel_cf_id'].str.startswith('f:', na=False)

# 3) 조건 2: 투자자 전용 ID 제외
cond2 = ~founder_master['rel_cf_id'].isin(pure_investor_ids)

# 4) 최종 필터링
founder_master_filtered = founder_master[cond1 & cond2].copy()

# %%
# 창업자 - 회사 관계 중복 확인
founder_master_filtered[['rel_p_id', 'rel_cf_id']].duplicated().sum()
# Out:
# np.int64(0)

# %%
# founder_master csv 파일로 저장!
founder_master_filtered.to_csv("./data/founder_master.csv", index=False)

# %% [markdown]
# ---

# %% [markdown]
# # 창업자와 회사 관계 : only 투자를 받은 회사 (invested_c_id)
#
# - with 채연님

# %%
# 1) [투자를 받은 회사 & 투자를 한 회사] 확인
overlap_ids_1 = set(inv['invested_c_id']) & set(inv['investor_cfp_id'])
print("겹치는 ID 개수:", len(overlap_ids_1))

# 조건1 : f: 가 아닌 행들
cond1 = ~founder_master['rel_cf_id'].str.startswith('f:', na=False)

# 조건2 : rel_cf_id 에서 1)을 포함하는 행들 + rel_cf_id 에서 invested_c_id가 들어있는 행들 => 투자를 받은 스타트업 회사
cond2 = founder_master['rel_cf_id'].isin(overlap_ids_1) | founder_master['rel_cf_id'].isin(inv['invested_c_id'])

invested_founder_master = founder_master[cond1 & cond2].copy()
invested_founder_master[['rel_p_id', 'rel_cf_id']].duplicated().sum()

# 중복제거
# dup_founder_master = founder_master.drop_duplicates(subset=['rel_cf_id'])
# print(f"중복제거 전 행수:", founder_master.shape)
# print(f"중복제거 후 행수:", dup_founder_master.shape)
# Out:
# 겹치는 ID 개수: 193
# np.int64(0)

# %%
# 투자받은 스타트업 회사 테이블
invested_founder_master.to_csv("./data/invested_founder_master.csv", index=False)

# %%
print(f"모든 스타트업의 창업자 수:",founder_master.shape[0])
print(f"투자만 행한 스타트업을 제외한 모든 스타트업의 창업자 수", founder_master_filtered.shape[0])

# 투자자인 창업자
investor_founder = founder_master.shape[0] - founder_master_filtered.shape[0]
print(f"\n투자만 행한 스타트업의 창업자 수:", investor_founder)

# 투자받은 스타트업
print(f"\n투자받은 스타트업의 창업자 수:", invested_founder_master.shape[0])
# Out:
# 모든 스타트업의 창업자 수: 59966
# 투자만 행한 스타트업을 제외한 모든 스타트업의 창업자 수 59516
#
# 투자만 행한 스타트업의 창업자 수: 450
#
# 투자받은 스타트업의 창업자 수: 14747

# %% [markdown]
# ---

# %% [markdown]
# # success_master 불러오기

# %%
success_master = pd.read_csv("./data/success_master.csv")

# %%
success_master[success_master['objects_cfpr_id'].str.startswith('c:')]
success_master
# Out:
#        objects_cfpr_id  founded_at closed_at                  description  \
# 0                  c:1  2005-10-17       NaN  Technology Platform Company
# 1                  c:1  2005-10-17       NaN  Technology Platform Company
# 2                  c:1  2005-10-17       NaN  Technology Platform Company
# 3               c:1001  2007-10-01       NaN    Social network aggregator
# 4              c:10014  2008-03-01       NaN  iPhone Ad Exchange Provider
# ...                ...         ...       ...                          ...
# 483534          r:9995         NaN       NaN                          NaN
# 483535          r:9996         NaN       NaN                          NaN
# 483536          r:9997         NaN       NaN                          NaN
# 483537          r:9998         NaN       NaN                          NaN
# 483538          r:9999         NaN       NaN                          NaN
#
#        country_code obj_city_fixed first_investment_at last_investment_at  \
# 0               USA        seattle                 NaN                NaN
# 1               USA        seattle                 NaN                NaN
# 2               USA        seattle                 NaN                NaN
# 3               USA  mountain view                 NaN                NaN
# 4               USA      palo alto                 NaN                NaN
# ...             ...            ...                 ...                ...
# 483534          NaN            NaN                 NaN                NaN
# 483535          NaN            NaN                 NaN                NaN
# 483536          NaN            NaN                 NaN                NaN
# 483537          NaN            NaN                 NaN                NaN
# 483538          NaN            NaN                 NaN                NaN
#
#         investment_rounds  invested_companies first_funding_at  \
# 0                       0                   0       2005-10-01
# 1                       0                   0       2005-10-01
# 2                       0                   0       2005-10-01
# 3                       0                   0              NaN
# 4                       0                   0              NaN
# ...                   ...                 ...              ...
# 483534                  0                   0              NaN
# 483535                  0                   0              NaN
# 483536                  0                   0              NaN
# 483537                  0                   0              NaN
# 483538                  0                   0              NaN
#
#        last_funding_at  funding_rounds  funding_total_usd  relationships  \
# 0           2008-05-19            3.00        39750000.00             17
# 1           2008-05-19            3.00        39750000.00             17
# 2           2008-05-19            3.00        39750000.00             17
# 3           2008-02-26            1.00         5000000.00             14
# 4           2008-09-01             NaN                NaN              9
# ...                ...             ...                ...            ...
# 483534             NaN            0.00               0.00              0
# 483535             NaN            0.00               0.00              0
# 483536             NaN            0.00               0.00              0
# 483537             NaN            0.00               0.00              0
# 483538             NaN            0.00               0.00              0
#
#        cat_obj_status obj_category_filled       cat_obj_overview  \
# 0           operating                 web  Software & Technology
# 1           operating                 web  Software & Technology
# 2           operating                 web  Software & Technology
# 3            acquired                 web  Software & Technology
# 4            acquired              mobile  Software & Technology
# ...               ...                 ...                    ...
# 483534      operating            software  Software & Technology
# 483535      operating            software  Software & Technology
# 483536      operating            software  Software & Technology
# 483537      operating            software  Software & Technology
# 483538      operating            software  Software & Technology
#
#        obj_state_filled  is_obj_funding_total_usd_private  success_flag  \
# 0                    WA                                 0             1
# 1                    WA                                 0             1
# 2                    WA                                 0             1
# 3                    CA                                 0             1
# 4                    CA                                 1             1
# ...                 ...                               ...           ...
# 483534              NaN                                 0             0
# 483535              NaN                                 0             0
# 483536              NaN                                 0             0
# 483537              NaN                                 0             0
# 483538              NaN                                 0             0
#
#        size_bin  time_to_last_round_months  funding_round_id  fr_c_id  ...  \
# 0           대형팀                      32.00            888.00      c:1  ...
# 1           대형팀                      32.00            889.00      c:1  ...
# 2           대형팀                      32.00           2312.00      c:1  ...
# 3           대형팀                        NaN           1644.00   c:1001  ...
# 4           대형팀                        NaN           6682.00  c:10014  ...
# ...         ...                        ...               ...      ...  ...
# 483534      NaN                        NaN               NaN      NaN  ...
# 483535      NaN                        NaN               NaN      NaN  ...
# 483536      NaN                        NaN               NaN      NaN  ...
# 483537      NaN                        NaN               NaN      NaN  ...
# 483538      NaN                        NaN               NaN      NaN  ...
#
#        is_last_round funded_year funded_quarter  cat_fr_type  num_fr_type  \
# 0               1.00     2005.00         2005Q4     series-a         1.00
# 1               0.00     2007.00         2007Q1     series-b         2.00
# 2               0.00     2008.00         2008Q2    series-c+         3.00
# 3               1.00     2008.00         2008Q1     series-a         1.00
# 4               1.00     2008.00         2008Q3         seed         0.00
# ...              ...         ...            ...          ...          ...
# 483534           NaN         NaN            NaN          NaN          NaN
# 483535           NaN         NaN            NaN          NaN          NaN
# 483536           NaN         NaN            NaN          NaN          NaN
# 483537           NaN         NaN            NaN          NaN          NaN
# 483538           NaN         NaN            NaN          NaN          NaN
#
#         log_participants  is_fr_raised_private  prev_round_date  \
# 0                   1.10                  0.00              NaN
# 1                   1.39                  0.00       2005-10-01
# 2                   1.61                  0.00              NaN
# 3                   1.39                  0.00              NaN
# 4                   0.69                  1.00              NaN
# ...                  ...                   ...              ...
# 483534               NaN                   NaN              NaN
# 483535               NaN                   NaN              NaN
# 483536               NaN                   NaN              NaN
# 483537               NaN                   NaN              NaN
# 483538               NaN                   NaN              NaN
#
#         round_tempo_days  round_tempo_months acquired_c_id acquisition_id  \
# 0                    NaN                 NaN           NaN            NaN
# 1                    NaN                 NaN           NaN            NaN
# 2                    NaN                 NaN           NaN            NaN
# 3                    NaN                 NaN        c:1001        1901.00
# 4                    NaN                 NaN       c:10014        3878.00
# ...                  ...                 ...           ...            ...
# 483534               NaN                 NaN           NaN            NaN
# 483535               NaN                 NaN           NaN            NaN
# 483536               NaN                 NaN           NaN            NaN
# 483537               NaN                 NaN           NaN            NaN
# 483538               NaN                 NaN           NaN            NaN
#
#         acquiring_c_id  acquired_at  is_acq_price_private price_amount_usd  \
# 0                  NaN          NaN                   NaN              NaN
# 1                  NaN          NaN                   NaN              NaN
# 2                  NaN          NaN                   NaN              NaN
# 3                  c:5   2009-08-10                  0.00      47500000.00
# 4              c:23054   2010-09-30                  1.00              NaN
# ...                ...          ...                   ...              ...
# 483534             NaN          NaN                   NaN              NaN
# 483535             NaN          NaN                   NaN              NaN
# 483536             NaN          NaN                   NaN              NaN
# 483537             NaN          NaN                   NaN              NaN
# 483538             NaN          NaN                   NaN              NaN
#
#         ipos_c_id  ipo_id first_public_at  valuation_amount_usd  \
# 0             NaN     NaN             NaN                   NaN
# 1             NaN     NaN             NaN                   NaN
# 2             NaN     NaN             NaN                   NaN
# 3             NaN     NaN             NaN                   NaN
# 4             NaN     NaN             NaN                   NaN
# ...           ...     ...             ...                   ...
# 483534        NaN     NaN             NaN                   NaN
# 483535        NaN     NaN             NaN                   NaN
# 483536        NaN     NaN             NaN                   NaN
# 483537        NaN     NaN             NaN                   NaN
# 483538        NaN     NaN             NaN                   NaN
#
#        ipo_raised_amount_usd is_ipos_valuation_private  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ...                      ...                       ...
# 483534                   NaN                       NaN
# 483535                   NaN                       NaN
# 483536                   NaN                       NaN
# 483537                   NaN                       NaN
# 483538                   NaN                       NaN
#
#         is_ipos_raised_private  offices_c_id n_offices
# 0                          NaN           c:1      2.00
# 1                          NaN           c:1      2.00
# 2                          NaN           c:1      2.00
# 3                          NaN        c:1001      1.00
# 4                          NaN       c:10014      1.00
# ...                        ...           ...       ...
# 483534                     NaN           NaN       NaN
# 483535                     NaN           NaN       NaN
# 483536                     NaN           NaN       NaN
# 483537                     NaN           NaN       NaN
# 483538                     NaN           NaN       NaN
#
# [483539 rows x 58 columns]

# %% [markdown]
# # success_master의 success_flag 집계

# %% [markdown]
# - founder_company_success : 창업자 x 회사 x 회사의 성공(success_flag)

# %%
# 1) success_master 에서 objects_cfpr_id가 [c:]인 것만 필터링
success_companies = success_master[success_master['objects_cfpr_id'].str.startswith('c:')].copy()

# 2) objects_cfpr_id 기준으로 success_flag 집계 
scs_flag = (success_companies
    .groupby('objects_cfpr_id')['success_flag']
    .first()
    .reset_index(name='success_flag')
    )
scs_flag    # ✅ c: 별 성공 플래그
# Out:
#        objects_cfpr_id  success_flag
# 0                  c:1             1
# 1                 c:10             1
# 2                c:100             1
# 3              c:10000             0
# 4              c:10001             0
# ...                ...           ...
# 196544         c:99940             0
# 196545          c:9995             0
# 196546          c:9996             0
# 196547          c:9997             0
# 196548          c:9998             0
#
# [196549 rows x 2 columns]

# %%
# founder_master와 scs_flag를 merge
founder_company_success = founder_master_filtered.merge(
    scs_flag,
    how = 'left',
    left_on = 'rel_cf_id',
    right_on = 'objects_cfpr_id'
)

founder_company_success     # ✅ 창업자 x 회사 x 회사의 성공(success_flag)
founder_company_success[['rel_p_id', 'rel_cf_id']].duplicated().sum()      # 중복 X
# Out:
# np.int64(0)

# %%
# 창업자 입장 : 평생 한번이라도 success를 경험했는지
founder_success = founder_company_success.groupby('rel_p_id').agg(
    founder_ever_success = ('success_flag', lambda x: int((x > 0).any()))
).reset_index()

founder_success     # ✅ founder_ever_success =1 : 해당 창업자(rel_p_id)는 한번이라도 success를 했다.
# Out:
#        rel_p_id  founder_ever_success
# 0          p:10                     1
# 1      p:100009                     0
# 2      p:100017                     0
# 3      p:100025                     0
# 4      p:100026                     0
# ...         ...                   ...
# 49738   p:99980                     1
# 49739   p:99982                     1
# 49740   p:99988                     0
# 49741   p:99994                     0
# 49742   p:99997                     1
#
# [49743 rows x 2 columns]

# %%
# founder_company_success와 founder_success을 merge
founder_with_success = founder_success.merge(
    founder_company_success,
    how = 'inner',
    on = 'rel_p_id',
)
founder_with_success        # ✅ 창업자(출생지, 최종학력, 학교, 전공) x 창업자의 성공경험 x 회사의 성공
# Out:
#        rel_p_id  founder_ever_success rel_cf_id  n_founding  is_past  \
# 0          p:10                     1       c:5           1        0
# 1      p:100009                     0  c:152329           2        0
# 2      p:100009                     0   c:81559           2        0
# 3      p:100017                     0   c:81564           1        0
# 4      p:100025                     0     c:287           1        0
# ...         ...                   ...       ...         ...      ...
# 59511   p:99982                     1   c:16993           2        1
# 59512   p:99982                     1   c:81541           2        0
# 59513   p:99988                     0   c:64683           1        0
# 59514   p:99994                     0    c:3643           1        0
# 59515   p:99997                     1   c:83651           1        0
#
#        sequence birthplace  degree_level                      subject  \
# 0             1       None           NaN  Computer Science / Software
# 1             1       None           NaN                         None
# 2             2       None           NaN                         None
# 3             1       None           NaN                         None
# 4             1       None           NaN                         None
# ...         ...        ...           ...                          ...
# 59511         1       None           NaN                         None
# 59512         2       None           NaN                         None
# 59513         1       None          2.00  Computer Science / Software
# 59514         1       None          2.00   Marketing / Communications
# 59515         7     Canada          2.00   Marketing / Communications
#
#                     institution graduated_at objects_cfpr_id  success_flag
# 0            harvard university         None             c:5          1.00
# 1                          None         None        c:152329          0.00
# 2                          None         None         c:81559          0.00
# 3                          None         None         c:81564          0.00
# 4                          None         None           c:287          0.00
# ...                         ...          ...             ...           ...
# 59511                      None         None         c:16993          1.00
# 59512                      None         None         c:81541          0.00
# 59513        bristol university   2004-01-01         c:64683          0.00
# 59514  madras, india university         None          c:3643          0.00
# 59515         ottawa university   1993-01-01         c:83651          1.00
#
# [59516 rows x 13 columns]

# %% [markdown]
# - 회사 기준 집계

# %%
success_companies.columns

# use_cols = ['objects_cfpr_id', 'relationships', 'obj_category_filled', 'size_bin']
# Out:
# Index(['objects_cfpr_id', 'founded_at', 'closed_at', 'description',
#        'country_code', 'obj_city_fixed', 'first_investment_at',
#        'last_investment_at', 'investment_rounds', 'invested_companies',
#        'first_funding_at', 'last_funding_at', 'funding_rounds',
#        'funding_total_usd', 'relationships', 'cat_obj_status',
#        'obj_category_filled', 'cat_obj_overview', 'obj_state_filled',
#        'is_obj_funding_total_usd_private', 'success_flag', 'size_bin',
#        'time_to_last_round_months', 'funding_round_id', 'fr_c_id', 'funded_at',
#        'funding_round_type', 'funding_round_code', 'raised_amount_usd',
#        'pre_money_valuation_usd', 'post_money_valuation_usd', 'participants',
#        'is_first_round', 'is_last_round', 'funded_year', 'funded_quarter',
#        'cat_fr_type', 'num_fr_type', 'log_participants',
#        'is_fr_raised_private', 'prev_round_date', 'round_tempo_days',
#        'round_tempo_months', 'acquired_c_id', 'acquisition_id',
#        'acquiring_c_id', 'acquired_at', 'is_acq_price_private',
#        'price_amount_usd', 'ipos_c_id', 'ipo_id', 'first_public_at',
#        'valuation_amount_usd', 'ipo_raised_amount_usd',
#        'is_ipos_valuation_private', 'is_ipos_raised_private', 'offices_c_id',
#        'n_offices'],
#       dtype='object')

# %%
company_with_success = success_companies.groupby('objects_cfpr_id').agg(
    success_flag  = ('success_flag', 'max'),
    relationships = ('relationships', 'first'),
    category      = ('obj_category_filled', 'first'),
    company_size  = ('size_bin', 'first')
).reset_index()

company_with_success        # ✅  회사(c) x 성공여부 x 관계수 x 산업 x 규모
# Out:
#        objects_cfpr_id  success_flag  relationships          category  \
# 0                  c:1             1             17               web
# 1                 c:10             1              6       games_video
# 2                c:100             1             12       games_video
# 3              c:10000             0              0   network_hosting
# 4              c:10001             0              0       games_video
# ...                ...           ...            ...               ...
# 196544         c:99940             0              5         ecommerce
# 196545          c:9995             0             14  public_relations
# 196546          c:9996             0             44        consulting
# 196547          c:9997             0              1            search
# 196548          c:9998             0              1         ecommerce
#
#        company_size
# 0               대형팀
# 1               대형팀
# 2               대형팀
# 3              초소형팀
# 4              초소형팀
# ...             ...
# 196544          대형팀
# 196545          대형팀
# 196546          대형팀
# 196547          소형팀
# 196548          소형팀
#
# [196549 rows x 5 columns]

# %%
print(founder_with_success.columns)
print(f"founder_with_success 행수:", founder_with_success.shape[0])
print('==='*30)
print(company_with_success.columns)
print(f"company_with_success 행수:", company_with_success.shape[0])
# Out:
# Index(['rel_p_id', 'founder_ever_success', 'rel_cf_id', 'n_founding',
#        'is_past', 'sequence', 'birthplace', 'degree_level', 'subject',
#        'institution', 'graduated_at', 'objects_cfpr_id', 'success_flag'],
#       dtype='object')
# founder_with_success 행수: 59516
# ==========================================================================================
# Index(['objects_cfpr_id', 'success_flag', 'relationships', 'category',
#        'company_size'],
#       dtype='object')
# company_with_success 행수: 196549

# %% [markdown]
# # founder_with_success, company_with_success 를 조인

# %%
successed_founder_company = founder_with_success.merge(
    company_with_success,
    how = 'left',
    on = 'objects_cfpr_id'
)

successed_founder_company[['rel_p_id', 'rel_cf_id']].duplicated().sum()     # 중복 X
successed_founder_company       # ✅ successed_founder_company : 창업자(출생지, 학교, 전공, 학위수준) x 회사(산업, 규모) 
                                # 나중에 마일스톤을 여기에 조인하면 될듯!
# Out:
#        rel_p_id  founder_ever_success rel_cf_id  n_founding  is_past  \
# 0          p:10                     1       c:5           1        0
# 1      p:100009                     0  c:152329           2        0
# 2      p:100009                     0   c:81559           2        0
# 3      p:100017                     0   c:81564           1        0
# 4      p:100025                     0     c:287           1        0
# ...         ...                   ...       ...         ...      ...
# 59511   p:99982                     1   c:16993           2        1
# 59512   p:99982                     1   c:81541           2        0
# 59513   p:99988                     0   c:64683           1        0
# 59514   p:99994                     0    c:3643           1        0
# 59515   p:99997                     1   c:83651           1        0
#
#        sequence birthplace  degree_level                      subject  \
# 0             1       None           NaN  Computer Science / Software
# 1             1       None           NaN                         None
# 2             2       None           NaN                         None
# 3             1       None           NaN                         None
# 4             1       None           NaN                         None
# ...         ...        ...           ...                          ...
# 59511         1       None           NaN                         None
# 59512         2       None           NaN                         None
# 59513         1       None          2.00  Computer Science / Software
# 59514         1       None          2.00   Marketing / Communications
# 59515         7     Canada          2.00   Marketing / Communications
#
#                     institution graduated_at objects_cfpr_id  success_flag_x  \
# 0            harvard university         None             c:5            1.00
# 1                          None         None        c:152329            0.00
# 2                          None         None         c:81559            0.00
# 3                          None         None         c:81564            0.00
# 4                          None         None           c:287            0.00
# ...                         ...          ...             ...             ...
# 59511                      None         None         c:16993            1.00
# 59512                      None         None         c:81541            0.00
# 59513        bristol university   2004-01-01         c:64683            0.00
# 59514  madras, india university         None          c:3643            0.00
# 59515         ottawa university   1993-01-01         c:83651            1.00
#
#        success_flag_y  relationships          category company_size
# 0                1.00         269.00            social          대형팀
# 1                0.00           2.00          software          중형팀
# 2                0.00           2.00        consulting          중형팀
# 3                0.00          15.00           medical          대형팀
# 4                0.00          21.00       games_video          대형팀
# ...               ...            ...               ...          ...
# 59511            1.00           2.00       games_video          중형팀
# 59512            0.00           3.00          software          대형팀
# 59513            0.00           1.00          software          소형팀
# 59514            0.00           3.00  public_relations          대형팀
# 59515            1.00           8.00        enterprise          대형팀
#
# [59516 rows x 17 columns]

# %%
# # 창업자 기준 성공 집계
# agg_founder_success = successed_founder_company.groupby('rel_p_id').agg(
#     n_founding           = ('n_founding', 'first'),              # n_founding : 창업자의 창업 횟수
#     founder_ever_success = ('founder_ever_success', 'max'),      # founder_ever_success : 창업자가 한번이라도 성공경험이 있는가
#     # success_flag         = ('success_flag_x', 'max'),            # success_flag : 창업자의 회사는 하나라도 성공했는가  
#     bplace               = ('birthplace', 'first'),              # 창업자 출생지
#     degree_level         = ('degree_level', 'first'),            # 창업자 학위 수준 
#     institution          = ('institution', 'first'),             # 창업자 출신 학교
#     subject              = ('subject', 'first')                  # 창업자 전공
#     # company_size         = ('size_bin', 'first'),              # company_size : 회사규모 -> 따로 집계 or 성공테이블 확인
#     # company_category     = ('obj_category_filled', 'first')    # 창업한 회사의 산업분야     -> 따로 집계 or 성공테이블 확인
# ).reset_index()

# display(agg_founder_success)     # ✅ agg_founder_success : 창업자 x 성공경험 여부 x 출생지 x 학위 x 학교 x 전공

# %% [markdown]
# # 데이터 csv 파일로 저장

# %%
successed_founder_company.to_csv('./data/successed_founder_company.csv', index=False, encoding='utf-8-sig')
print("CSV 파일 저장 완료! (인덱스 제외)")
# Out:
# CSV 파일 저장 완료! (인덱스 제외)

# %% [markdown]
# ---
