# %% [markdown]
# ### 20251124

# %% [markdown]
# #### import library

# %%
#########################
# 변경자: 소희
# 변경일자: 25.11.25
# 변경내용: 
# 1. 필요한 라이브러리 추가 호출 및 정리
# 2. commit 연습
#########################

#초기 설정및 시스템 라이브러리
import platform
import warnings

# 데이터 시각화 라이브러리
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
print(platform.system())
warnings.filterwarnings('ignore')

# 행,열,결과값 생략 없이 보기,세팅
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)

# 시각화 OS별 한글폰트 설정
if platform.system() == 'Windows':
    plt.rcParams['font.family'] = 'Malgun Gothic'  # Windows 폰트 설정
elif platform.system() == 'Mac':
    plt.rcParams['font.family'] = 'AppleGothic'  # Mac 폰트 설정
# Out:
# Darwin

# %% [markdown]
# #### Load files

# %%
#########################
# 변경자: 소희
# 변경일자: 25.11.25
# 변경내용: 
# 1. csv파일은 용량이 너무 커서 폴더생성(./data/)하여 gitignore에 추가하는 것 추천.
#########################

# Load Files
Acquisitions = pd.read_csv("./data/acquisitions.csv")
Degrees = pd.read_csv("./data/degrees.csv")
FundingRounds = pd.read_csv("./data/funding_rounds.csv")
Funds = pd.read_csv("./data/funds.csv")
Investments = pd.read_csv("./data/investments.csv")
Ipos = pd.read_csv("./data/ipos.csv")
Milestones = pd.read_csv("./data/milestones.csv")
Objects = pd.read_csv("./data/objects.csv")
Offices = pd.read_csv("./data/offices.csv")
People = pd.read_csv("./data/people.csv")
Relationships = pd.read_csv("./data/relationships.csv")

print("="*60)
print("Dataset 로드 완료!")
print("="*60)
# Out:
# ...
# Dataset 로드 완료!
# ...

# %%
#########################
# 변경자: 소희
# 변경일자: 25.11.25
# 변경내용: 
# 1. columns()를 columns로 변경
# 2. 한 cell output에서 확인하기 위해 display적용 
#########################

display(Acquisitions.columns)
display(Degrees.columns)
display(FundingRounds.columns)
display(Funds.columns)
# Out:
# Index(['id', 'acquisition_id', 'acquiring_object_id', 'acquired_object_id',
#        'term_code', 'price_amount', 'price_currency_code', 'acquired_at',
#        'source_url', 'source_description', 'created_at', 'updated_at'],
#       dtype='object')
# Index(['id', 'object_id', 'degree_type', 'subject', 'institution',
#        'graduated_at', 'created_at', 'updated_at'],
#       dtype='object')
# Index(['id', 'funding_round_id', 'object_id', 'funded_at',
#        'funding_round_type', 'funding_round_code', 'raised_amount_usd',
#        'raised_amount', 'raised_currency_code', 'pre_money_valuation_usd',
#        'pre_money_valuation', 'pre_money_currency_code',
#        'post_money_valuation_usd', 'post_money_valuation',
#        'post_money_currency_code', 'participants', 'is_first_round',
#        'is_last_round', 'source_url', 'source_description', 'created_by',
#        'created_at', 'updated_at'],
#       dtype='object')
# ...

# %%
#########################
# 변경자: 수아
# 변경일자: 25.11.25
# 변경내용: 
# 1. 각 테이블 info() 확인
#########################

display(Acquisitions.info())
display(Degrees.info())
display(FundingRounds.info())
display(Funds.info())
display(Investments.info())
display(Ipos.info())
display(Milestones.info())
display(Objects.info())
display(Offices.info())
display(People.info())
display(Relationships.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9562 entries, 0 to 9561
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   9562 non-null   int64
#  1   acquisition_id       9562 non-null   int64
#  2   acquiring_object_id  9562 non-null   object
#  3   acquired_object_id   9561 non-null   object
#  4   term_code            1906 non-null   object
#  5   price_amount         9562 non-null   float64
#  6   price_currency_code  9558 non-null   object
#  7   acquired_at          9533 non-null   object
#  8   source_url           8566 non-null   object
#  9   source_description   8590 non-null   object
#  10  created_at           9562 non-null   object
#  11  updated_at           9562 non-null   object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 896.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109610 entries, 0 to 109609
# ...

# %%
print("Hello")
print("Hello")
# Out:
# Hello
# Hello

# %%
#########################
# 변경자: 채연
# 변경일자: 25.11.25
# 변경내용: 
# 1. 각 테이블 info() 확인
#########################

display(Acquisitions.describe())
display(Degrees.describe())
display(FundingRounds.describe())
display(Funds.describe())
display(Investments.describe())
display(Ipos.describe())
display(Milestones.describe())
display(Objects.describe())
display(Offices.describe())
display(People.describe())
display(Relationships.describe())
# Out:
#                 id  acquisition_id  price_amount
# count  9562.000000     9562.000000  9.562000e+03
# mean   4781.500000     5266.795859  3.886191e+08
# std    2760.455971     3009.738380  2.660374e+10
# min       1.000000        1.000000  0.000000e+00
# 25%    2391.250000     2692.250000  0.000000e+00
# 50%    4781.500000     5197.500000  0.000000e+00
# 75%    7171.750000     7858.750000  5.000000e+05
# max    9562.000000    10529.000000  2.600000e+12
#                  id
# count  109610.00000
# mean    54805.50000
# std     31641.82584
# min         1.00000
# 25%     27403.25000
# 50%     54805.50000
# 75%     82207.75000
# max    109610.00000
#                  id  funding_round_id  raised_amount_usd  raised_amount  \
# count  52928.000000      52928.000000       5.292800e+04   5.292800e+04
# mean   28962.894536      28962.894536       7.946092e+06   8.056120e+06
# std    16821.871803      16821.871803       4.216820e+07   4.479914e+07
# ...
