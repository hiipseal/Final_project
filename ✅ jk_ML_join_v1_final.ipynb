# %%
#초기 설정및 시스템 라이브러리
import platform
import warnings

# 데이터 시각화 라이브러리
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
print(platform.system())
warnings.filterwarnings('ignore')

# 통계 라이브러리
from scipy import stats
from scipy.stats import chi2_contingency, mannwhitneyu, kruskal
import statsmodels.api as sm

# 머신러닝
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import AgglomerativeClustering, KMeans
from sklearn.metrics import silhouette_score

from scipy.cluster.hierarchy import linkage, dendrogram

# 행,열,결과값 생략 없이 보기,세팅
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_colwidth', None)

# 한글 폰트 설정
pd.set_option("display.float_format","{:.2f}".format)
# OS에 따라 다른 폰트 지정
if platform.system() == 'Darwin':   # macOS
    plt.rcParams['font.family'] = 'AppleGothic'
elif platform.system() == 'Windows':  # Windows
    plt.rcParams['font.family'] = 'Malgun Gothic'
else:  # Linux (예: Colab, Ubuntu)
    plt.rcParams['font.family'] = 'NanumGothic'
# Out:
# Darwin

# %%
import pandas as pd

# 날짜 컬럼 방지
def read_csv_auto_dates(path):
    # 1) 전체 파일을 먼저 읽기
    temp = pd.read_csv(path, low_memory=False)
    
    # 2) _at 로 끝나는 컬럼 자동 탐지
    date_cols = [col for col in temp.columns if col.endswith('_at')]
    
    # 3) 다시 날짜 컬럼을 datetime 으로 읽기
    return pd.read_csv(path, parse_dates=date_cols, low_memory=False)

# Load Files (전처리)
acq = read_csv_auto_dates("./clean_data_v1/clean_acquisitions_final.csv")
deg = read_csv_auto_dates("./clean_data_v1/clean_degrees_final.csv")
frs = read_csv_auto_dates("./clean_data_v1/clean_fr_final.csv")
fds = read_csv_auto_dates("./clean_data_v1/clean_funds_final.csv")
inv = read_csv_auto_dates("./clean_data_v1/clean_investments_final.csv")
ipo = read_csv_auto_dates("./clean_data_v1/clean_ipos_final.csv")
mil = read_csv_auto_dates("./clean_data_v1/clean_milestones_final.csv")
obj = read_csv_auto_dates("./clean_data_v1/clean_objects_final.csv")
peo = read_csv_auto_dates("./clean_data_v1/clean_people_final.csv")
off = read_csv_auto_dates("./clean_data_v1/clean_offices_final.csv")
rel = read_csv_auto_dates("./clean_data_v1/clean_relationships_final.csv")

# statistic join
startup_office = read_csv_auto_dates("./statistic_join/startup_office.csv")

# %%
startup_office
# Out:
#        objects_cfpr_id founded_at closed_at                  description  \
# 0                  c:1 2005-10-17       NaT  Technology Platform Company
# 1                  c:1 2005-10-17       NaT  Technology Platform Company
# 2                  c:1 2005-10-17       NaT  Technology Platform Company
# 3                  c:1 2005-10-17       NaT  Technology Platform Company
# 4                  c:1 2005-10-17       NaT  Technology Platform Company
# ...                ...        ...       ...                          ...
# 531076          r:9995        NaT       NaT                          NaN
# 531077          r:9996        NaT       NaT                          NaN
# 531078          r:9997        NaT       NaT                          NaN
# 531079          r:9998        NaT       NaT                          NaN
# 531080          r:9999        NaT       NaT                          NaN
#
#        country_code obj_city_fixed first_investment_at last_investment_at  \
# 0               USA        seattle                 NaT                NaT
# 1               USA        seattle                 NaT                NaT
# 2               USA        seattle                 NaT                NaT
# 3               USA        seattle                 NaT                NaT
# 4               USA        seattle                 NaT                NaT
# ...             ...            ...                 ...                ...
# 531076          NaN            NaN                 NaT                NaT
# 531077          NaN            NaN                 NaT                NaT
# 531078          NaN            NaN                 NaT                NaT
# 531079          NaN            NaN                 NaT                NaT
# 531080          NaN            NaN                 NaT                NaT
#
#         investment_rounds  invested_companies first_funding_at  \
# 0                       0                   0       2005-10-01
# 1                       0                   0       2005-10-01
# 2                       0                   0       2005-10-01
# 3                       0                   0       2005-10-01
# 4                       0                   0       2005-10-01
# ...                   ...                 ...              ...
# 531076                  0                   0              NaT
# 531077                  0                   0              NaT
# 531078                  0                   0              NaT
# 531079                  0                   0              NaT
# 531080                  0                   0              NaT
#
#        last_funding_at  funding_rounds  funding_total_usd  relationships  \
# 0           2008-05-19            3.00        39750000.00             17
# 1           2008-05-19            3.00        39750000.00             17
# 2           2008-05-19            3.00        39750000.00             17
# 3           2008-05-19            3.00        39750000.00             17
# 4           2008-05-19            3.00        39750000.00             17
# ...                ...             ...                ...            ...
# 531076             NaT            0.00               0.00              0
# 531077             NaT            0.00               0.00              0
# 531078             NaT            0.00               0.00              0
# 531079             NaT            0.00               0.00              0
# 531080             NaT            0.00               0.00              0
#
#        cat_obj_status obj_category_filled       cat_obj_overview  \
# 0           operating                 web  Software & Technology
# 1           operating                 web  Software & Technology
# 2           operating                 web  Software & Technology
# 3           operating                 web  Software & Technology
# 4           operating                 web  Software & Technology
# ...               ...                 ...                    ...
# 531076      operating            software  Software & Technology
# 531077      operating            software  Software & Technology
# 531078      operating            software  Software & Technology
# 531079      operating            software  Software & Technology
# 531080      operating            software  Software & Technology
#
#        obj_state_filled  is_obj_funding_total_usd_private  success_flag  \
# 0                    WA                                 0             1
# 1                    WA                                 0             1
# 2                    WA                                 0             1
# 3                    WA                                 0             1
# 4                    WA                                 0             1
# ...                 ...                               ...           ...
# 531076              NaN                                 0             0
# 531077              NaN                                 0             0
# 531078              NaN                                 0             0
# 531079              NaN                                 0             0
# 531080              NaN                                 0             0
#
#        size_bin  round_tempo_months  time_to_last_round_months  \
# 0           대형팀               16.00                      32.00
# 1           대형팀               16.00                      32.00
# 2           대형팀               16.00                      32.00
# 3           대형팀               16.00                      32.00
# 4           대형팀               16.00                      32.00
# ...         ...                 ...                        ...
# 531076      NaN                 NaN                        NaN
# 531077      NaN                 NaN                        NaN
# 531078      NaN                 NaN                        NaN
# 531079      NaN                 NaN                        NaN
# 531080      NaN                 NaN                        NaN
#
#         funding_round_id fr_c_id  funded_at  raised_amount_usd  participants  \
# 0                 888.00     c:1 2005-10-01         5250000.00          2.00
# 1                 888.00     c:1 2005-10-01         5250000.00          2.00
# 2                 889.00     c:1 2007-01-01         9500000.00          3.00
# 3                 889.00     c:1 2007-01-01         9500000.00          3.00
# 4                 889.00     c:1 2007-01-01         9500000.00          3.00
# ...                  ...     ...        ...                ...           ...
# 531076               NaN     NaN        NaT                NaN           NaN
# 531077               NaN     NaN        NaT                NaN           NaN
# 531078               NaN     NaN        NaT                NaN           NaN
# 531079               NaN     NaN        NaT                NaN           NaN
# 531080               NaN     NaN        NaT                NaN           NaN
#
#         is_first_round  is_last_round  num_fr_type  is_fr_raised_private  \
# 0                 0.00           1.00         1.00                  0.00
# 1                 0.00           1.00         1.00                  0.00
# 2                 0.00           0.00         2.00                  0.00
# 3                 0.00           0.00         2.00                  0.00
# 4                 0.00           0.00         2.00                  0.00
# ...                ...            ...          ...                   ...
# 531076             NaN            NaN          NaN                   NaN
# 531077             NaN            NaN          NaN                   NaN
# 531078             NaN            NaN          NaN                   NaN
# 531079             NaN            NaN          NaN                   NaN
# 531080             NaN            NaN          NaN                   NaN
#
#        cat_fr_type  investments_id invested_c_id investor_cfp_id  \
# 0         series-a         1289.00           c:1           f:430
# 1         series-a         1290.00           c:1             f:3
# 2         series-b         1291.00           c:1             f:4
# 3         series-b         1292.00           c:1           f:430
# 4         series-b         1293.00           c:1             f:3
# ...            ...             ...           ...             ...
# 531076         NaN             NaN           NaN             NaN
# 531077         NaN             NaN           NaN             NaN
# 531078         NaN             NaN           NaN             NaN
# 531079         NaN             NaN           NaN             NaN
# 531080         NaN             NaN           NaN             NaN
#
#         acquisition_id acquiring_c_id acquired_at  is_acq_price_private  \
# 0                  NaN            NaN         NaT                   NaN
# 1                  NaN            NaN         NaT                   NaN
# 2                  NaN            NaN         NaT                   NaN
# 3                  NaN            NaN         NaT                   NaN
# 4                  NaN            NaN         NaT                   NaN
# ...                ...            ...         ...                   ...
# 531076             NaN            NaN         NaT                   NaN
# 531077             NaN            NaN         NaT                   NaN
# 531078             NaN            NaN         NaT                   NaN
# 531079             NaN            NaN         NaT                   NaN
# 531080             NaN            NaN         NaT                   NaN
#
#         price_amount_usd  ipo_id first_public_at  valuation_amount_usd  \
# 0                    NaN     NaN             NaT                   NaN
# 1                    NaN     NaN             NaT                   NaN
# 2                    NaN     NaN             NaT                   NaN
# 3                    NaN     NaN             NaT                   NaN
# 4                    NaN     NaN             NaT                   NaN
# ...                  ...     ...             ...                   ...
# 531076               NaN     NaN             NaT                   NaN
# 531077               NaN     NaN             NaT                   NaN
# 531078               NaN     NaN             NaT                   NaN
# 531079               NaN     NaN             NaT                   NaN
# 531080               NaN     NaN             NaT                   NaN
#
#         ipo_raised_amount_usd  is_ipos_valuation_private  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
# ...                       ...                        ...
# 531076                    NaN                        NaN
# 531077                    NaN                        NaN
# 531078                    NaN                        NaN
# 531079                    NaN                        NaN
# 531080                    NaN                        NaN
#
#         is_ipos_raised_private  reinvest_flag  n_offices
# 0                          NaN          False       2.00
# 1                          NaN          False       2.00
# 2                          NaN          False       2.00
# 3                          NaN           True       2.00
# 4                          NaN           True       2.00
# ...                        ...            ...        ...
# 531076                     NaN          False        NaN
# 531077                     NaN          False        NaN
# 531078                     NaN          False        NaN
# 531079                     NaN          False        NaN
# 531080                     NaN          False        NaN
#
# [531081 rows x 50 columns]

# %% [markdown]
# ## [조인] ML용 피처를 위한 조인

# %% [markdown]
# ### 회사 기준 n_offices 만들기

# %%
# 🔗1️⃣ 조인할 n_offices 만들기 -> startup_office 집계  
cnt_offices = startup_office.groupby('objects_cfpr_id')['n_offices'].max().reset_index(name='n_offices')
cnt_offices
# Out:
#        objects_cfpr_id  n_offices
# 0                  c:1       2.00
# 1                 c:10       1.00
# 2                c:100       1.00
# 3              c:10000        NaN
# 4              c:10001        NaN
# ...                ...        ...
# 462615          r:9995        NaN
# 462616          r:9996        NaN
# 462617          r:9997        NaN
# 462618          r:9998        NaN
# 462619          r:9999        NaN
#
# [462620 rows x 2 columns]

# %% [markdown]
# ### founder만 추출해서 학교, 전공, 학위 만들기

# %%
rd = (
    rel
    .merge(deg, how='left', left_on='rel_p_id', right_on='degrees_p_id')
)
rd_founder = rd[rd['cat_rel_title'] == 'Founder'].copy()
rd_founder  # rel_p_id, rel_cf_id, degree_level, cat_degrees_subject, institution_normalized
# Out:
#         relationship_id  rel_p_id rel_cf_id   start_at end_at  is_past  \
# 0                     1       p:2       c:1        NaT    NaT        0
# 1                     1       p:2       c:1        NaT    NaT        0
# 11                    9      p:10       c:5        NaT    NaT        0
# 12                   10      p:11       c:5        NaT    NaT        1
# 15                   14      p:16    c:7299        NaT    NaT        1
# ...                 ...       ...       ...        ...    ...      ...
# 563564           480741   p:29245  c:286154 2004-01-01    NaT        1
# 563629           480794  p:254302  c:286157        NaT    NaT        0
# 563631           480796  p:254302  c:286160        NaT    NaT        0
# 563632           480797  p:268562  c:286160        NaT    NaT        0
# 563808           480895  p:268590  c:286215        NaT    NaT        0
#
#         sequence                                title  has_end_date  \
# 0              8    Co-Founder/CEO/Board of Directors             0
# 1              8    Co-Founder/CEO/Board of Directors             0
# 11             1  Founder and CEO, Board Of Directors             0
# 12             1                           Co-Founder             0
# 15             2                      Founder and CEO             0
# ...          ...                                  ...           ...
# 563564         1                              Founder             0
# 563629         3                              Founder             0
# 563631         4              Co-founder and Director             0
# 563632         1                   Co-founder and CEO             0
# 563808         1                           Co-Founder             0
#
#        cat_rel_title degrees_p_id degree_type  \
# 0            Founder          p:2          BS
# 1            Founder          p:2          BS
# 11           Founder         p:10         NaN
# 12           Founder         p:11   No degree
# 15           Founder         p:16          BA
# ...              ...          ...         ...
# 563564       Founder          NaN         NaN
# 563629       Founder          NaN         NaN
# 563631       Founder          NaN         NaN
# 563632       Founder          NaN         NaN
# 563808       Founder          NaN         NaN
#
#                                         subject  \
# 0       Electrical Engineering/Computer Science
# 1                           Applied Mathematics
# 11                             Computer Science
# 12                                          NaN
# 15                 Computer Information Systems
# ...                                         ...
# 563564                                      NaN
# 563629                                      NaN
# 563631                                      NaN
# 563632                                      NaN
# 563808                                      NaN
#
#                                institution graduated_at  \
# 0       University of California, Berkeley   1994-01-01
# 1       University of California, Berkeley   1994-01-01
# 11                      Harvard University          NaT
# 12                      Harvard University          NaT
# 15               Colorado State University          NaT
# ...                                    ...          ...
# 563564                                 NaN          NaT
# 563629                                 NaN          NaT
# 563631                                 NaN          NaT
# 563632                                 NaN          NaT
# 563808                                 NaN          NaT
#
#        cat_degrees_degree_type  degree_level  is_degree_missing  \
# 0            Bachelor’s degree          2.00               0.00
# 1            Bachelor’s degree          2.00               0.00
# 11                         NaN           NaN               1.00
# 12           Bachelor’s degree          2.00               0.00
# 15           Bachelor’s degree          2.00               0.00
# ...                        ...           ...                ...
# 563564                     NaN           NaN                NaN
# 563629                     NaN           NaN                NaN
# 563631                     NaN           NaN                NaN
# 563632                     NaN           NaN                NaN
# 563808                     NaN           NaN                NaN
#
#                 cat_degrees_subject           institution_normalized
# 0       Computer Science / Software  california, berkeley university
# 1       Computer Science / Software  california, berkeley university
# 11      Computer Science / Software               harvard university
# 12                              NaN               harvard university
# 15      Computer Science / Software        colorado state university
# ...                             ...                              ...
# 563564                          NaN                              NaN
# 563629                          NaN                              NaN
# 563631                          NaN                              NaN
# 563632                          NaN                              NaN
# 563808                          NaN                              NaN
#
# [77705 rows x 20 columns]

# %% [markdown]
# ### rel_cf_id, rel_p_id 쌍 기준 집계

# %%
# rd_founder를 회사단위로 집계
c_rd_founder = (
    rd_founder.groupby(['rel_p_id', 'rel_cf_id']).agg(
    degree_level = ('degree_level', 'max'),
    subject      = ('cat_degrees_subject', 'first'),
    institution  = ('institution_normalized', 'first')
).reset_index()
)
c_rd_founder = c_rd_founder[c_rd_founder['rel_cf_id'].str.startswith('c:')].copy()
c_rd_founder
# Out:
#        rel_p_id rel_cf_id  degree_level                      subject  \
# 0          p:10       c:5           NaN  Computer Science / Software
# 2      p:100009  c:152329           NaN                         None
# 3      p:100009   c:81559           NaN                         None
# 4      p:100017   c:81564           NaN                         None
# 5      p:100025     c:287           NaN                         None
# ...         ...       ...           ...                          ...
# 61822   p:99982   c:16993           NaN                         None
# 61823   p:99982   c:81541           NaN                         None
# 61824   p:99988   c:64683          2.00  Computer Science / Software
# 61825   p:99994    c:3643          2.00   Marketing / Communications
# 61826   p:99997   c:83651          2.00   Marketing / Communications
#
#                 institution
# 0        harvard university
# 2                      None
# 3                      None
# 4                      None
# 5                      None
# ...                     ...
# 61822                  None
# 61823                  None
# 61824    bristol university
# 61825  louisiana university
# 61826     ottawa university
#
# [59966 rows x 5 columns]

# %% [markdown]
# ### 사람 기준 n_founding 만들기

# %%
# 창업경험 수 n_founding
cnt_founding = c_rd_founder.groupby('rel_p_id')['rel_cf_id'].nunique().reset_index(name='n_founding')
cnt_founding
# Out:
#        rel_p_id  n_founding
# 0          p:10           1
# 1      p:100009           2
# 2      p:100017           1
# 3      p:100025           1
# 4      p:100026           1
# ...         ...         ...
# 50016   p:99980           4
# 50017   p:99982           2
# 50018   p:99988           1
# 50019   p:99994           1
# 50020   p:99997           1
#
# [50021 rows x 2 columns]

# %%
# 🔗 c_rd_founder <- cnt_founding 조인
rd_founding = (
    c_rd_founder.merge(
    cnt_founding,
    how = 'left',
    on  = 'rel_p_id'
    )
)
rd_founding
# Out:
#        rel_p_id rel_cf_id  degree_level                      subject  \
# 0          p:10       c:5           NaN  Computer Science / Software
# 1      p:100009  c:152329           NaN                         None
# 2      p:100009   c:81559           NaN                         None
# 3      p:100017   c:81564           NaN                         None
# 4      p:100025     c:287           NaN                         None
# ...         ...       ...           ...                          ...
# 59961   p:99982   c:16993           NaN                         None
# 59962   p:99982   c:81541           NaN                         None
# 59963   p:99988   c:64683          2.00  Computer Science / Software
# 59964   p:99994    c:3643          2.00   Marketing / Communications
# 59965   p:99997   c:83651          2.00   Marketing / Communications
#
#                 institution  n_founding
# 0        harvard university           1
# 1                      None           2
# 2                      None           2
# 3                      None           1
# 4                      None           1
# ...                     ...         ...
# 59961                  None           2
# 59962                  None           2
# 59963    bristol university           1
# 59964  louisiana university           1
# 59965     ottawa university           1
#
# [59966 rows x 6 columns]

# %%
# 스타트업 유형 클러스터링에 사용할 주요 피처
"""
1. 'obj_category_filled'        -> obj : objects_cfpr_id 
2. 'obj_city_fixed'             -> obj : objects_cfpr_id
3. 'institution_normalized'     -> deg : degrees_p_id 
4. 'cat_degree_subject'         -> deg : degrees_p_id 
4. 'degree_level'               -> deg : degrees_p_id 
5. 'n_offices'                  -> startup_info : objects_cfpr_id
6. 'n_founding'                 -> rel : rel_p_id, rel_cf_id 
"""
# Out:
# "\n1. 'obj_category_filled'        -> obj : objects_cfpr_id \n2. 'obj_city_fixed'             -> obj : objects_cfpr_id\n3. 'institution_normalized'     -> deg : degrees_p_id \n4. 'cat_degree_subject'         -> deg : degrees_p_id \n4. 'degree_level'               -> deg : degrees_p_id \n5. 'n_offices'                  -> startup_info : objects_cfpr_id\n6. 'n_founding'                 -> rel : rel_p_id, rel_cf_id \n"

# %% [markdown]
# ### obj에서 only investor 제거

# %%
# 0) obj에서 회사(c:)만
obj_c = obj[obj['objects_cfpr_id'].str.startswith('c:', na=False)].copy()

# 1) investments에서 investor로 등장한 c:
c_investors = set(
    inv.loc[
        inv['investor_cfp_id'].str.startswith('c:', na=False),
        'investor_cfp_id'
    ].dropna().unique()
)

# 2) investments에서 invested(투자받은 회사)로 등장한 c:
c_invested = set(
    inv.loc[
        inv['invested_c_id'].str.startswith('c:', na=False),
        'invested_c_id'
    ].dropna().unique()
)

# 3) investor에만 있는 c: (투자만 한 회사)  = 제거
c_only_investor = c_investors - c_invested

# 4) obj의 c:에서 투자만 한 회사 제거
obj_c_filtered = obj_c[~obj_c['objects_cfpr_id'].isin(c_only_investor)].copy()

# %%
# 🔗 산업, 도시, 직원수 집계
agg_obj_c_filtered = (
    obj_c_filtered.groupby('objects_cfpr_id').agg(
    category = ('obj_category_filled', 'first'),
    city     = ('obj_city_fixed', 'first'),
    relationships = ('relationships', 'max')
    ).reset_index()
)
agg_obj_c_filtered
# Out:
#        objects_cfpr_id          category               city  relationships
# 0                  c:1               web            seattle             17
# 1                 c:10       games_video        culver city              6
# 2                c:100       games_video          san mateo             12
# 3              c:10000   network_hosting               None              0
# 4              c:10001       games_video               None              0
# ...                ...               ...                ...            ...
# 194146         c:99940         ecommerce      san francisco              5
# 194147          c:9995  public_relations           san jose             14
# 194148          c:9996        consulting       falls church             44
# 194149          c:9997            search        los angeles              1
# 194150          c:9998         ecommerce  pacific palisades              1
#
# [194151 rows x 4 columns]

# %%
# 🔗 최종 조인 : cnt_offices(objects_cfpr_id), rd_founding(rel_cf_id), agg_obj_c_filtered(objects_cfpr_id)
startup_df = (
    agg_obj_c_filtered
        .merge(cnt_offices, how='left', on='objects_cfpr_id')
        .merge(rd_founding, how='left', left_on='objects_cfpr_id', right_on='rel_cf_id')
)
startup_df
# Out:
#        objects_cfpr_id          category               city  relationships  \
# 0                  c:1               web            seattle             17
# 1                  c:1               web            seattle             17
# 2                 c:10       games_video        culver city              6
# 3                 c:10       games_video        culver city              6
# 4                c:100       games_video          san mateo             12
# ...                ...               ...                ...            ...
# 213294         c:99940         ecommerce      san francisco              5
# 213295          c:9995  public_relations           san jose             14
# 213296          c:9996        consulting       falls church             44
# 213297          c:9997            search        los angeles              1
# 213298          c:9998         ecommerce  pacific palisades              1
#
#         n_offices rel_p_id rel_cf_id  degree_level  \
# 0            2.00      p:2       c:1          2.00
# 1            2.00  p:59304       c:1          2.00
# 2            1.00     p:39      c:10          2.00
# 3            1.00     p:40      c:10           NaN
# 4            1.00   p:1274     c:100           NaN
# ...           ...      ...       ...           ...
# 213294       1.00      NaN       NaN           NaN
# 213295       1.00      NaN       NaN           NaN
# 213296       1.00      NaN       NaN           NaN
# 213297       1.00      NaN       NaN           NaN
# 213298       1.00  p:16907    c:9998          3.00
#
#                             subject  \
# 0       Computer Science / Software
# 1       Computer Science / Software
# 2       Computer Science / Software
# 3                              None
# 4                              None
# ...                             ...
# 213294                          NaN
# 213295                          NaN
# 213296                          NaN
# 213297                          NaN
# 213298   Marketing / Communications
#
#                                              institution  n_founding
# 0                        california, berkeley university        2.00
# 1       london school of economics and political science        1.00
# 2                                    michigan university        2.00
# 3                                                   None        1.00
# 4                                                   None        1.00
# ...                                                  ...         ...
# 213294                                               NaN         NaN
# 213295                                               NaN         NaN
# 213296                                               NaN         NaN
# 213297                                               NaN         NaN
# 213298                    southern california university        1.00
#
# [213299 rows x 11 columns]

# %% [markdown]
# ## [최종] 회사기준 1행으로 만들기 : 집계

# %%
# 1행 회사단위로 집계!!! 최종
startup_ml_df = (
    startup_df.groupby('objects_cfpr_id').agg(
        category      = ('category', 'first'),
        city          = ('city', 'first'),
        n_offices     = ('n_offices', 'max'),
        relationships = ('relationships', 'max'),
        degree_level  = ('degree_level', 'max'),
        # subject, institution을 아래와 같이 집계 : 결측 제외 후 첫값 가져오기 (📌 범주형 대표값이 필요할 때 1순위 패턴)
        # 1.두 컬럼은 논리적으로 독립 / 2.한 사람에게 birthplace만 있는데 학교만 없는 경우 많음 / 3.정보 손실 최소화    
        subject       = ('subject',
                         lambda x: x.dropna().iloc[0] if x.notna().any() else np.nan),
        inst          = ('institution',
                         lambda x: x.dropna().iloc[0] if x.notna().any() else np.nan),
        n_founding    = ('n_founding', 'max')
        )
    ).reset_index()

# %%
startup_ml_df
# Out:
#        objects_cfpr_id          category               city  n_offices  \
# 0                  c:1               web            seattle       2.00
# 1                 c:10       games_video        culver city       1.00
# 2                c:100       games_video          san mateo       1.00
# 3              c:10000   network_hosting               None        NaN
# 4              c:10001       games_video               None        NaN
# ...                ...               ...                ...        ...
# 194146         c:99940         ecommerce      san francisco       1.00
# 194147          c:9995  public_relations           san jose       1.00
# 194148          c:9996        consulting       falls church       1.00
# 194149          c:9997            search        los angeles       1.00
# 194150          c:9998         ecommerce  pacific palisades       1.00
#
#         relationships  degree_level                      subject  \
# 0                  17          2.00  Computer Science / Software
# 1                   6          2.00  Computer Science / Software
# 2                  12          4.00  Computer Science / Software
# 3                   0           NaN                          NaN
# 4                   0           NaN                          NaN
# ...               ...           ...                          ...
# 194146              5           NaN                          NaN
# 194147             14           NaN                          NaN
# 194148             44           NaN                          NaN
# 194149              1           NaN                          NaN
# 194150              1          3.00   Marketing / Communications
#
#                                    inst  n_founding
# 0       california, berkeley university        2.00
# 1                   michigan university        2.00
# 2                   stanford university        1.00
# 3                                   NaN         NaN
# 4                                   NaN         NaN
# ...                                 ...         ...
# 194146                              NaN         NaN
# 194147                              NaN         NaN
# 194148                              NaN         NaN
# 194149                              NaN         NaN
# 194150   southern california university        1.00
#
# [194151 rows x 9 columns]

# %%
startup_ml_df.isna().mean().sort_values(ascending=False)
# Out:
# subject           0.91
# degree_level      0.91
# inst              0.90
# n_founding        0.79
# city              0.57
# n_offices         0.55
# category          0.01
# objects_cfpr_id   0.00
# relationships     0.00
# dtype: float64

# %% [markdown]
# ## [저장] startup_ml_df csv 파일로 저장!

# %%
# startup_ml_df.to_csv("./data/startup_ml_final.csv", index=False)
# print("머신러닝용 파일 startup_ml_final.csv 저장완료!!!")
